# %% [markdown]
# #  Vertex Inference Unified
#
# This notebook uses the unified `google-genai` library (imported as `from google import genai`). It supports:
# - **Vertex AI Backend:** Uploads videos to GCS during the 'Prepare' step.
# - **Gemini API Backend:** Uploads videos using the **File API** during the 'Prepare' step.
#
# **Pipeline Steps:**
# 1.  **Import Libraries & Configure.**
# 2.  **Config** - Set up the configuration for the pipeline, including the model, model config, prompts, and prompt config.
# 2.  **Initialize Clients:** Set up AI client and Storage client.
# 3.  **(Only the first time) Fetch Dataset:** Downloads metadata from HuggingFace.
# 4.  **(Only the first time on each API type) Download, Extract & Prepare Videos:** Downloads, extracts, uploads (GCS/File API). Updates metadata.
# 5.  **Bulk Inference (Async):** Performs inference using pre-uploaded video resources.
# 6.  **Single Prompt Testing (UI):** Allows interactive testing of the video with prompts

# %% [markdown]
# ### Notes:
#
# 1. After switching from Vertex to Gemini and vice versa, be sure to follow the steps:
#     - Run all cells in order to re-upload the videos to the correct storage client, you can enable the SKIP_DOWNLOAD and SKIP_EXTRACT flags to skip the download and extraction steps. Only the upload step is needed
#
# 2. Gemini API's file client has a expiry time of 1 day or so for the uploaded files. You may need to follow the steps above to re-upload the files.

# %% [markdown]
# ## Import Libraries

# %%
# Cell 1: Imports (Corrected for `google.genai`)
import os
import csv
import json
import logging
import time
import random
import requests
import datetime
import zipfile
import math
import sys
import asyncio
from typing import Dict, List, Optional, Set, Tuple, Any
from collections import defaultdict
from pathlib import Path
import shutil
import subprocess
import tempfile
import fractions

# Google Cloud & AI Libraries (Unified SDK)
try:
    import google.genai as genai
    from google.genai import types
    from google.genai import errors as genai_errors
    from google.api_core import exceptions as api_core_exceptions
    # GCS Client (Optional, for Vertex Mode)
    try:
        from google.cloud import storage
        GCS_AVAILABLE = True
    except ImportError:
        print("INFO: google-cloud-storage not found. Vertex AI GCS operations unavailable.")
        storage = None
        GCS_AVAILABLE = False
    print("`google.genai` SDK and helpers imported successfully.")
except ImportError as e:
     print(f"ERROR: Failed to import Google libraries: {e}. Install: pip install google-genai google-api-core google-cloud-storage")
     genai = None; types = None; genai_errors = None; api_core_exceptions = None
     storage = None; GCS_AVAILABLE = False
     raise ImportError("FATAL: `google.genai` or `google-api-core` SDK not found.")

# Data Handling & Progress
from datasets import load_dataset
import pandas as pd
from tqdm.notebook import tqdm

# UI Elements
import ipywidgets as widgets
from IPython.display import display, Markdown, HTML, clear_output

# Async in Notebook
import nest_asyncio
nest_asyncio.apply()
# Out:
# `google.genai` SDK and helpers imported successfully.

# %% [markdown]
# ## Config Settings

# %%
# --- GCP Configuration ---
# PROJECT_ID = "your_google_cloud_project_id" # Your Google Cloud Project ID (Needed for GCS and Vertex AI mode)
# LOCATION = "your_google_cloud_region"      # Your Google Cloud Region (Needed for Vertex AI mode)
# GCS_BUCKET = "your_gcs_bucket" # Your GCS bucket name (Needed for video storage), required for Vertex AI mode

PROJECT_ID = "tiktokllm" # Your Google Cloud Project ID (Needed for GCS and Vertex AI mode)
LOCATION = "us-central1"      # Your Google Cloud Region (Needed for Vertex AI mode)
GCS_BUCKET = "seekdeep-ml-storage" # Your GCS bucket name (Needed for video storage)

# --- Choose Backend Mode ---
# Set USE_VERTEX to True to use the Vertex AI backend (requires ADC or service account auth).
# Set USE_VERTEX to False to use the Gemini API backend (requires GEMINI_API_KEY).
USE_VERTEX = False  # <-- CHANGE THIS TO True TO USE VERTEX AI

# --- Gemini API Key (Only required if USE_VERTEX is False) ---
# IMPORTANT: Replace with your actual Gemini API Key if USE_VERTEX is False.
# Loading from environment variables (GOOGLE_API_KEY) or a secure secrets manager.
GEMINI_API_KEY = "AIzaSyC1pFApqINjnjKh4-P2IJqZMEDLPY4DpAI"  # Replace with your actual Gemini API Key


# --- File Paths ---
DATASET_CSV = "dataset.csv"               # Input dataset metadata from HuggingFace
METADATA_FILE = "video_metadata_vertex_inj_correct_mcq.csv" if USE_VERTEX else "video_metadata_non_vertex_inj_correct_mcq.csv"      # Stores video info: video_id, local_path, gcs_uri (if Vertex), question data
RESULTS_FILE = "results_ccot_full_inference.csv"              # Output file for inference predictions
DOWNLOADS_DIR = "downloads"               # Directory for downloaded zip file
EXTRACTED_VIDEOS_DIR = "extracted_videos" # Directory storing extracted .mp4 files locally
SPEED_VIDEOS_DIR = "speed_videos"         # Stores sped up/slowed down videos
HF_CACHE_DIR = "./hf_cache"               # Cache directory for HuggingFace datasets

# --- Step 1: Fetch Dataset Configuration ---
HF_DATASET_NAME = "lmms-lab/AISG_Challenge" # HuggingFace dataset identifier
HF_DATASET_SPLIT = "test"                 # Dataset split to use
SKIP_FETCH = False                        # Set True to skip fetching if DATASET_CSV exists

# --- Step 2: Download & Prepare Videos Configuration ---
VIDEO_ZIP_URL = "https://huggingface.co/datasets/lmms-lab/AISG_Challenge/resolve/main/Benchmark-AllVideos-HQ-Encoded-challenge.zip?download=true"
ZIP_FILE_NAME = "all_videos.zip"
SKIP_DOWNLOAD_ZIP = True                 # Set True to skip downloading if zip exists
SKIP_EXTRACT = True                   # Set True to skip extraction if videos exist locally
SKIP_PREPARE = True                    # Set True to skip video preparation (GCS upload for Vertex, metadata update)
MAX_VIDEOS_TO_PROCESS = None              # Limit videos for testing (e.g., 5), None for all
UPLOAD_BATCH_SIZE_GCS = 10                # Batch size for GCS uploads (Vertex mode only)

# --- Inference Configuration ---
# Choose a model name compatible with your selected method (Vertex AI or Gemini API)

# Examples:

# Vertex AI: gemini-2.0-flash, gemini-2.0-flash-lite, gemini-2.0-pro-exp-02-05, gemini-2.0-flash-thinking-exp-01-21
# Rate limits: https://cloud.google.com/vertex-ai/generative-ai/docs/quotas#gemini-2.0-flash
# Basically 500 requests per minute for 2.0-flash and 2.0-flash-lite (unlimited), 10 requests per minute for 2.0-pro-exp-02-05, gemini-2.5-flash-preview-04-17

# Gemini API: gemini-2.0-flash, gemini-2.0-flash-lite, gemini-2.0-flash-thinking-exp-01-21, gemini-2.5-pro-exp-03-25
# Rate limits: https://ai.google.dev/gemini-api/docs/rate-limits#tier-1
# For free tier: 30 requests per minute for 2.0-flash and 2.0-flash-lite, 10 requests per minute for 2.0-pro-exp-02-05
# For tier-1: 2000 requests per minute for 2.0-flash and 2.0-flash-lite (have to pay), 10 requests per minute for 2.0-pro-exp-02-05 and gemini-2.0-flash-thinking-exp-01-21, gemini-2.5-flash-preview-04-17

# 1.0=normal speed, 0.5=half speed, etc.
VIDEO_SPEED_FACTOR = 0.5

# --- Setup Derived Paths & Directories ---
zip_file_path = Path(DOWNLOADS_DIR) / ZIP_FILE_NAME
extracted_videos_path = Path(EXTRACTED_VIDEOS_DIR)
speed_videos_path = Path(SPEED_VIDEOS_DIR) / str(VIDEO_SPEED_FACTOR)
Path(DOWNLOADS_DIR).mkdir(parents=True, exist_ok=True)
extracted_videos_path.mkdir(parents=True, exist_ok=True)
speed_videos_path.mkdir(parents=True, exist_ok=True)
Path(HF_CACHE_DIR).mkdir(parents=True, exist_ok=True)

# --- Logging Configuration ---
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s', handlers=[logging.StreamHandler(sys.stdout)])
logger = logging.getLogger(__name__)

# --- Configuration Validation & Display --- #
warnings_found = False
if USE_VERTEX:
    if not PROJECT_ID or PROJECT_ID == "your-gcp-project-id":
        logger.error("Vertex AI mode requires PROJECT_ID to be set.")
        warnings_found = True
    if not LOCATION:
        logger.error("Vertex AI mode requires LOCATION to be set.")
        warnings_found = True
    if not GCS_BUCKET or GCS_BUCKET == "your-gcs-bucket-name":
        logger.error("Vertex AI mode requires GCS_BUCKET for video uploads.")
        warnings_found = True
    if not GCS_AVAILABLE:
        logger.error("Vertex AI mode requires 'google-cloud-storage', but it's not installed.")
        warnings_found = True
else: # Gemini API Mode
    # Check API Key (explicit or env var)
    effective_api_key = GEMINI_API_KEY if GEMINI_API_KEY != "YOUR_API_KEY_HERE" else os.environ.get("GOOGLE_API_KEY")
    if not effective_api_key:
        logger.error("Gemini API mode requires GEMINI_API_KEY or GOOGLE_API_KEY environment variable.")
        warnings_found = True
    else:
        # Don't store the key in the config display if loaded from env
        if GEMINI_API_KEY == "YOUR_API_KEY_HERE" and os.environ.get("GOOGLE_API_KEY"):
            GEMINI_API_KEY = "(Loaded from GOOGLE_API_KEY env var)"
        logger.info("Gemini API mode configured. Videos will be uploaded via File API.")

if warnings_found:
     print("\n\n************************* WARNING *************************")
     print("Configuration errors detected above. Execution might fail.")
     print("***********************************************************\n")
# Out:
# 2025-04-25 19:42:07,308 - INFO - Gemini API mode configured. Videos will be uploaded via File API.

# %% [markdown]
# # Main Model Selection (Innovation 1)
# Agentic CoT - Chain of Thought + Summary

# %% [markdown]
# ## 1. Select CoT Model and Summary Model

# %% [markdown]
# ### CoT output models

# %%
# To See All Available Models, Go into the CoT_ouput_models.py file

from models.CoT_ouput_models import get_cot_model

CoT_model_list = ["gemini-2.0-flash","gemini-2.5-flash-preview-04-17", "gemini-2.5-pro-preview-03-25"]

MODEL_NAME, SYSTEM_PROMPT, PROMPT_TEMPLATES, CONFIG, REQUESTS_PER_MINUTE, MAX_RETRIES, MAX_ASYNC_WORKERS = get_cot_model(CoT_model_list[2])

# %% [markdown]
# ### Summary Model Selection

# %%
# To see all available models, go into the Summary_models.py file
from models.Summary_models import get_summary_model
summary_model_list = ["gemini-2.0-flash-ver1", "gemini-2.0-flash-ver2", "gemini-2.0-flash-ver3"]

QUESTION_MODEL_NAME, QUESTION_SYSTEM_PROMPT, QUESTION_CONFIG = get_summary_model(summary_model_list[0])

# %% [markdown]
# **Summary Model Prompt Versions (Gemini Flash) Comparison**
#
# Concise summary of different post-processing approaches for LLM outputs with `thinking` blocks.
#
#
# #### Version 1:  No Yap Model (Extractor Model)
#
# *   **Action:** Extracts final answer, minimal changes.
# *   **`thinking`:** Mostly ignored; extracts text after it.
# *   **Output:** Final answer only (For MCQ, letter only). "No yap".
#
# #### Version 2: Detailed Reformatter & Explainer
#
# *   **Action:** Answer first, then detailed *synthesized* explanation.
# *   **`thinking`:** Source for detailed step-by-step explanation; removes examiner notes.
# *   **Output:** `Answer \n\n Explanation: \n [Detailed Synth. Explanation]`
#
# #### Version 3: Light Touch Reformatter & Preserver
#
# *   **Action:** Answer first, then *original* `thinking` block.
# *   **`thinking`:** Preserved in output (within ``` ```).
# *   **Output:** `Answer \n\n ```thinking\n[Original Thinking]\n``` `

# %% [markdown]
# # Basic Initialization

# %% [markdown]
# ## Initialize Google Cloud Clients

# %%
storage_client = None
ai_client = None

# --- Initialize Generative AI Client (`google.genai`) --- #
display(Markdown("### Initializing Generative AI Client (`google.genai`)"))
try:
    if USE_VERTEX:
        display(Markdown(f"Vertex AI backend (Project: {PROJECT_ID}, Loc: {LOCATION})..."))
        if not PROJECT_ID or not LOCATION or PROJECT_ID == "your-gcp-project-id":
             raise ValueError("PROJECT_ID/LOCATION invalid for Vertex AI.")
        # Initialize Client for Vertex
        ai_client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)
        display(Markdown(f"✅ Vertex AI Client Initialized."))
    else: # Gemini API Mode
        display(Markdown("Gemini API backend (using API Key)..."))
        effective_api_key = GEMINI_API_KEY if GEMINI_API_KEY != "YOUR_API_KEY_HERE" else os.environ.get("GOOGLE_API_KEY")
        if not effective_api_key:
             if os.environ.get("GOOGLE_API_KEY"): effective_api_key = None # Client uses env var
             else: raise ValueError("Gemini API Key required but not found.")
        # Initialize Client for Gemini API
        ai_client = genai.Client(api_key=effective_api_key, vertexai=False)
        display(Markdown(f"✅ Gemini API Client Initialized."))

except ValueError as ve: display(Markdown(f"❌ **Config Error:** {ve}")); ai_client = None
except Exception as e: display(Markdown(f"❌ **AI Client Error:** {e}.")); logger.error("AI Client Init Failed", exc_info=True); ai_client = None

# --- Initialize Storage Client (ONLY for Vertex AI mode) --- #
if USE_VERTEX:
    display(Markdown("### Initializing GCS Client (Vertex Mode Only)"))
    if not GCS_AVAILABLE: display(Markdown("❌ GCS lib missing.")); raise RuntimeError("Missing GCS lib.")
    if not GCS_BUCKET or GCS_BUCKET == "your-gcs-bucket-name": display(Markdown("❌ GCS_BUCKET needed.")); raise ValueError("GCS_BUCKET required.")
    try:
        storage_client = storage.Client(project=PROJECT_ID)
        if not storage_client.bucket(GCS_BUCKET).exists(): display(Markdown(f"⚠️ GCS Bucket `{GCS_BUCKET}` inaccessible."))
        else: display(Markdown(f"✅ GCS Client Initialized (Bucket: '{GCS_BUCKET}')."))
    except Exception as e:
        display(Markdown(f"❌ **GCS Client Error:** {e}.")); logger.error("GCS Client Init Failed", exc_info=True)
        if not SKIP_PREPARE: raise RuntimeError("GCS client failed.")
        else: display(Markdown("⚠️ GCS client failed, but skipping prep."))
else:
    display(Markdown("### Initializing Gemini API Client (File API)"))
    try:
        storage_client = ai_client.files
    except Exception as e:
        display(Markdown(f"❌ **Gemini File API Client Error:** {e}.")); logger.error("Gemini API Client Init Failed", exc_info=True)
    display(Markdown(f"✅ Gemini File API Client Initialized."))

# --- Final Checks --- #
if ai_client is None: raise RuntimeError("AI client failed.")
if USE_VERTEX and storage_client is None and not SKIP_PREPARE: raise RuntimeError("GCS client failed for Vertex prep.")
display(Markdown("✅ Client initialization complete."))
# Out:
# ### Initializing Generative AI Client (`google.genai`)
# Gemini API backend (using API Key)...
# ✅ Gemini API Client Initialized.
# ### Initializing Gemini API Client (File API)
# ✅ Gemini File API Client Initialized.
# ✅ Client initialization complete.

# %% [markdown]
# ## Utility Functions

# %%
# --- File/Data Handling ---
def load_processed_qids(filename: str) -> Set[str]:
    processed_qids = set()
    if Path(filename).is_file():
        try:
            df = pd.read_csv(filename, usecols=['qid'], dtype={'qid': str}, on_bad_lines='warn')
            processed_qids = set(df['qid'].dropna().unique())
            logger.info(f"Loaded {len(processed_qids)} processed QIDs from {filename}")
        except Exception as e:
            logger.warning(f"Could not read QIDs from {filename}: {e}. Assuming zero processed.")
    return processed_qids

def download_file_with_progress(url: str, destination: Path):
    logger.info(f"Downloading {url} to {destination}...")
    try:
        response = requests.get(url, stream=True, timeout=600)
        response.raise_for_status()
        total_size = int(response.headers.get('content-length', 0))
        block_size = 1024 * 1024
        with open(destination, 'wb') as f, tqdm(
            desc=f"Downloading {destination.name}", total=total_size, unit='iB', unit_scale=True, unit_divisor=1024
        ) as bar:
            for data in response.iter_content(block_size):
                size = f.write(data)
                bar.update(size)
        if total_size != 0 and bar.n != total_size:
            destination.unlink(missing_ok=True)
            raise RuntimeError(f"Download size mismatch for {destination.name}.")
        logger.info(f"Successfully downloaded {destination}")
    except Exception as e:
        destination.unlink(missing_ok=True)
        logger.error(f"Download failed for {url}: {e}")
        raise

def extract_zip(zip_path: Path, extract_to: Path):
    logger.info(f"Extracting {zip_path.name} to {extract_to}...")
    try:
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            members = [m for m in zip_ref.namelist() if not m.startswith('__MACOSX/') and not m.endswith('.DS_Store')]
            with tqdm(total=len(members), desc=f"Extracting {zip_path.name}") as pbar:
                for member in members:
                    zip_ref.extract(member=member, path=extract_to)
                    pbar.update(1)
        logger.info(f"Successfully extracted {zip_path} to {extract_to}")
    except Exception as e:
        logger.error(f"Extraction error: {e}")
        raise
    
def move_videos_to_main_directory(base_path):
    """Find all MP4 files in subdirectories and move them to the main directory."""
    logger.info(f"Moving all videos to main directory: {base_path}")
    moved_count = 0
    failed_count = 0
    
    # Find all MP4 files in subdirectories (but not in the main directory)
    for file_path in list(base_path.glob('**/*.mp4')):
        # Skip files already in the main directory or hidden Mac files
        if file_path.parent == base_path or file_path.name.startswith('._'):
            continue
            
        # Destination in the main directory
        dest_path = base_path / file_path.name
        
        try:
            # Move the file
            shutil.move(str(file_path), str(dest_path))
            moved_count += 1
            if moved_count % 50 == 0:
                logger.info(f"Moved {moved_count} videos so far...")
        except Exception as e:
            logger.error(f"Error moving {file_path}: {e}")
            failed_count += 1
    
    logger.info(f"Moved {moved_count} videos to main directory. Failed: {failed_count}")
    

def create_or_update_metadata(metadata_path: str, dataset_df: pd.DataFrame, video_updates: Dict[str, Dict]):
    try:
        required_cols = ['video_id', 'qid']
        update_cols = ['local_path', 'gcs_uri', 'file_api_name', 'status']
        dtype_map = {'video_id': str, 'qid': str} # Ensure IDs are strings

        if not Path(metadata_path).is_file():
            logger.info(f"Creating metadata file: {metadata_path}")
            meta_df = dataset_df.copy()
            for col in update_cols: meta_df[col] = pd.NA
            meta_df['status'] = 'pending'
        else:
            logger.debug(f"Loading existing metadata: {metadata_path}")
            meta_df = pd.read_csv(metadata_path, dtype=dtype_map)
            for col in update_cols: # Add missing update columns if needed
                 if col not in meta_df.columns: meta_df[col] = pd.NA

        if not all(col in meta_df.columns for col in required_cols):
            raise ValueError(f"Metadata missing required columns ({required_cols}).")

        updates_df = pd.DataFrame.from_dict(video_updates, orient='index')
        updates_df.index.name = 'video_id'
        updates_df.reset_index(inplace=True)
        updates_df['video_id'] = updates_df['video_id'].astype(str)

        # Use merge for robust updating across potentially multiple rows per video_id
        # First, prepare updates DF with only the necessary columns (video_id + update_cols)
        merge_cols = ['video_id'] + [col for col in update_cols if col in updates_df.columns]
        updates_to_merge = updates_df[merge_cols].drop_duplicates(subset=['video_id'], keep='last')

        # Merge, prioritizing updates
        # Suffixes help identify original vs update cols if needed, but update will overwrite
        merged_df = pd.merge(meta_df, updates_to_merge, on='video_id', how='left', suffixes=('', '_update'))

        # Apply the updates
        for col in update_cols:
            update_col_name = col + '_update'
            if update_col_name in merged_df.columns:
                # Fill NAs in original col with update col, then drop update col
                meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
                # Alternative: Directly update where update is not NA
                # meta_df[col] = np.where(merged_df[update_col_name].notna(), merged_df[update_col_name], merged_df[col])

        meta_df.to_csv(metadata_path, index=False, encoding='utf-8')
        logger.info(f"Metadata file '{metadata_path}' updated with {len(video_updates)} video records.")

    except Exception as e:
        logger.error(f"Error updating metadata {metadata_path}: {e}", exc_info=True)
        raise

def load_metadata_for_inference(metadata_file: str = METADATA_FILE) -> Dict[str, List[Dict]]:
    if not Path(metadata_file).is_file(): return {}
    video_questions = defaultdict(list)
    required_col = 'gcs_uri' if USE_VERTEX else 'file_api_name'
    try:
        df = pd.read_csv(metadata_file, dtype=str).fillna('')
        if 'video_id' not in df.columns or required_col not in df.columns:
            logger.error(f"Metadata missing 'video_id' or '{required_col}'.")
            return {}
        valid_df = df[df['video_id'].astype(bool) & df[required_col].astype(bool)]
        if len(valid_df) == 0:
             logger.warning(f"No videos found with '{required_col}' in {metadata_file}. Check Step 4.")
             return {}
        for video_id, group in valid_df.groupby('video_id'):
             video_questions[video_id] = group.to_dict('records')
        logger.info(f"Loaded {len(video_questions)} videos ({len(valid_df)} questions) with valid IDs for inference.")
        return dict(video_questions)
    except Exception as e:
        logger.error(f"Error loading metadata for inference: {e}", exc_info=True)
        return {}

# --- Upload/Verification Helpers ---
def upload_to_gcs(storage_client, bucket_name: str, source_file_path: Path, destination_blob_name: str) -> Optional[str]:
    if not GCS_AVAILABLE or storage_client is None or not source_file_path.is_file(): return None
    try:
        blob = storage_client.bucket(bucket_name).blob(destination_blob_name)
        blob.upload_from_filename(str(source_file_path))
        gcs_uri = f"gs://{bucket_name}/{destination_blob_name}"
        logger.debug(f"GCS OK: {source_file_path} -> {gcs_uri}")
        return gcs_uri
    except Exception as e:
        logger.error(f"GCS Fail: {source_file_path}. Error: {e}")
        return None

def upload_via_file_api(storage_client, local_path: Path, display_name: str) -> Optional[str]:
    if storage_client is None or not local_path.is_file(): return None
    try:
        logger.debug(f"Uploading {local_path} via File API...")
        uploaded_file = storage_client.upload(file=local_path)
        logger.info(f"File API OK: {local_path} -> {uploaded_file.name}")
        return uploaded_file.name
    except Exception as e:
        logger.error(f"File API Fail: {local_path}. Error: {e}", exc_info=True)
        return None

def verify_gcs_file_exists(storage_client, gcs_uri: str) -> bool:
    if not GCS_AVAILABLE or storage_client is None or not gcs_uri: return False
    try:
        exists = storage.Blob.from_string(gcs_uri, client=storage_client).exists()
        if not exists: logger.warning(f"GCS verify failed: {gcs_uri}")
        return exists
    except Exception as e:
        logger.error(f"Error verifying GCS {gcs_uri}: {e}")
        return False

def verify_file_api_resource_exists(storage_client, file_api_name: str) -> bool:
    if not storage_client or not file_api_name: return False
    try:
        _ = storage_client.get(name=file_api_name) # Sync get for verification
        return True
    except Exception as e:
        logger.error(f"Error verifying File API {file_api_name}: {e}")
        return False

def verify_local_file_exists(local_path: str) -> bool:
    exists = Path(local_path).is_file() if local_path else False
    if not exists: logger.warning(f"Local verify failed: {local_path}")
    return exists

# --- Prompt Building ---
def build_prompt(question_info: dict) -> str:
    question = question_info.get("question", "")
    q_type = question_info.get("question_type", "default")
    template = PROMPT_TEMPLATES.get(q_type, PROMPT_TEMPLATES["default"])
    # if q_type is MCQ
    if q_type == "Multiple-choice Question with a Single Correct Answer":
        return template.format(question=question).strip() + "\n" + "E. None of the above"
    return template.format(question=question).strip() + "\n" + question_info.get("question_prompt").strip()

# --- Rate Limiter ---
class AsyncRateLimiter:
    """
    An asyncio-compatible token bucket rate limiter.

    Args:
        rate (int): The maximum number of requests allowed per period.
        period (float): The time period in seconds (default: 60 for RPM).
        capacity (int, optional): The maximum burst capacity. Defaults to `rate`.
    """
    def __init__(self, rate: int, period: float = 60.0, capacity: Optional[int] = None):
        if rate <= 0:
            raise ValueError("Rate must be positive")
        if period <= 0:
            raise ValueError("Period must be positive")

        self.rate = rate
        self.period = float(period)
        self.capacity = float(capacity if capacity is not None else rate)
        self._tokens = self.capacity # Start full
        self._last_refill_time = time.monotonic()
        self._lock = asyncio.Lock()

    def _get_tokens_per_second(self) -> float:
        return self.rate / self.period

    async def _refill(self):
        """Replenishes tokens based on elapsed time. Must be called under lock."""
        now = time.monotonic()
        elapsed = now - self._last_refill_time
        if elapsed > 0:
            tokens_to_add = elapsed * self._get_tokens_per_second()
            self._tokens = min(self.capacity, self._tokens + tokens_to_add)
            self._last_refill_time = now

    async def acquire(self):
        """
        Acquires a token, waiting if necessary.
        """
        async with self._lock:
            await self._refill() # Refill based on time since last acquire/refill

            while self._tokens < 1:
                # Calculate how long to wait for 1 token
                tokens_needed = 1.0 - self._tokens
                wait_time = tokens_needed / self._get_tokens_per_second()

                # Release the lock before sleeping
                lock_released = True
                try:
                    self._lock.release()
                    logger.debug(f"Rate limit hit. Waiting for {wait_time:.3f}s for next token.")
                    await asyncio.sleep(wait_time)
                finally:
                    # Re-acquire the lock if it was released
                    if lock_released:
                        await self._lock.acquire()

                # Refill again after waiting, as more time has passed
                await self._refill()

            # Consume a token
            self._tokens -= 1.0

# %% [markdown]
# # Download, Extract & Prepare Dataset

# %% [markdown]
# ## Fetch Dataset from HuggingFace

# %%
dataset_path = Path(DATASET_CSV)

if dataset_path.is_file() and SKIP_FETCH:
    logger.info(f"Dataset file '{DATASET_CSV}' exists and SKIP_FETCH is True. Skipping.")
    display(Markdown(f"✅ Skipping fetch: Found existing `{DATASET_CSV}`."))
    # Load the existing dataframe for use in Step 2
    try:
        dataset_df = pd.read_csv(dataset_path, dtype=str) # Load all as string initially
        logger.info(f"Loaded existing dataset from {DATASET_CSV} ({len(dataset_df)} rows).")
    except Exception as e:
        logger.error(f"Failed to load existing dataset file {DATASET_CSV}: {e}")
        display(Markdown(f"❌ Error loading existing `{DATASET_CSV}`: {e}. Please delete the file or set SKIP_FETCH=False."))
        raise
else:
    logger.info(f"Fetching dataset '{HF_DATASET_NAME}' (split: '{HF_DATASET_SPLIT}') from HuggingFace...")
    try:
        dataset = load_dataset(HF_DATASET_NAME, split=HF_DATASET_SPLIT, cache_dir=HF_CACHE_DIR)
        dataset_df = dataset.to_pandas()
        # Ensure key columns are strings
        for col in ['qid', 'video_id', 'question', 'question_type']:
             if col in dataset_df.columns:
                 dataset_df[col] = dataset_df[col].astype(str)
        dataset_df.to_csv(dataset_path, index=False, encoding='utf-8')
        logger.info(f"Successfully fetched dataset and saved to {DATASET_CSV} ({len(dataset_df)} rows).")
        display(Markdown(f"✅ Dataset fetched and saved to `{DATASET_CSV}` ({len(dataset_df)} rows)."))
        display(dataset_df.head())
    except Exception as e:
        logger.error(f"Failed to fetch or save dataset: {e}", exc_info=True)
        display(Markdown(f"❌ **Error fetching dataset:** {e}. Check connection, dataset name/split, cache dir permissions."))
        raise RuntimeError("Dataset fetching failed. Cannot continue.")

# Ensure dataset_df is loaded if skipping fetch didn't load it (e.g., first run with skip=True and no file)
if 'dataset_df' not in locals():
    if dataset_path.is_file():
        try:
            dataset_df = pd.read_csv(dataset_path, dtype=str)
        except Exception as e:
            logger.error(f"Critical error: Could not load dataset from {DATASET_CSV} after attempting fetch/skip: {e}")
            raise
    else:
        raise RuntimeError(f"Critical error: Dataset DataFrame not loaded and file {DATASET_CSV} not found.")
# Out:
# 2025-04-24 03:14:00,378 - INFO - Fetching dataset 'lmms-lab/AISG_Challenge' (split: 'test') from HuggingFace...
# Generating test split:   0%|          | 0/1500 [00:00<?, ? examples/s]
# 2025-04-24 03:14:06,473 - INFO - Successfully fetched dataset and saved to dataset.csv (1500 rows).
# ✅ Dataset fetched and saved to `dataset.csv` (1500 rows).
#       qid     video_id                                      question_type  \
# 0  0008-0  sj81PWrerDk                        Primary Open-ended Question
# 1  0008-1  sj81PWrerDk                    Paraphrased Open-ended Question
# 2  0008-2  sj81PWrerDk                  Correctly-led Open-ended Question
# 3  0008-3  sj81PWrerDk                    Wrongly-led Open-ended Question
# 4  0008-7  sj81PWrerDk  Multiple-choice Question with a Single Correct...
#
#                  capability  \
# 0  Plot Attribute (Montage)
# 1  Plot Attribute (Montage)
# 2  Plot Attribute (Montage)
# 3  Plot Attribute (Montage)
# 4  Plot Attribute (Montage)
#
#                                             question duration  \
# 0  What is the difference between the action of t...     8.85
# 1  Can you describe how the actions of the last p...     8.85
# 2  Did the last person open the bottle without us...     8.85
# 3  Did the last person in the video open the bott...     8.85
# 4  How does the last person in the video open the...     8.85
#
#                                      question_prompt answer  \
# 0  Please state your answer with a brief explanat...
# 1  Please state your answer with a brief explanat...
# 2  Please state your answer with a brief explanat...
# 3  Please state your answer with a brief explanat...
# 4  E. None of the above\nSelect one best answer t...
#
#                                   youtube_url
# 0  https://www.youtube.com/shorts/sj81PWrerDk
# 1  https://www.youtube.com/shorts/sj81PWrerDk
# 2  https://www.youtube.com/shorts/sj81PWrerDk
# 3  https://www.youtube.com/shorts/sj81PWrerDk
# 4  https://www.youtube.com/shorts/sj81PWrerDk

# %% [markdown]
# ## Download, Extract, and Prepare Videos
#
# Downloads, extracts, and uploads videos (to GCS or File API). Updates `video_metadata.csv`.

# %%
dataset_path = Path(DATASET_CSV)
dataset_df = pd.read_csv(dataset_path, dtype=str)

# %% [markdown]
# ### Download Video Archive

# %%
display(Markdown("### Downloading Archive"))
if zip_file_path.is_file() and SKIP_DOWNLOAD_ZIP:
    display(Markdown(f"✅ Skipping download: Found `{zip_file_path}`."))
else:
    try: download_file_with_progress(VIDEO_ZIP_URL, zip_file_path); display(Markdown(f"✅ Downloaded: `{zip_file_path}`."))
    except Exception as e:
        display(Markdown(f"❌ **Download Error:** {e}."))
        if not SKIP_EXTRACT or not SKIP_PREPARE: raise RuntimeError(f"Download failed.")
        else: display(Markdown("⚠️ Download failed, skipping steps."))
# Out:
# ### Downloading Archive
# ✅ Skipping download: Found `downloads/all_videos.zip`.

# %% [markdown]
# ### Extract Video Archive

# %%
display(Markdown("### Extracting Archive"))
if any(extracted_videos_path.glob('*.mp4')) and SKIP_EXTRACT:
    display(Markdown(f"✅ Skipping extraction: Files in `{extracted_videos_path}`."))
elif not zip_file_path.is_file():
    display(Markdown(f"❌ Cannot extract: `{zip_file_path}` missing."))
    if not SKIP_PREPARE: raise RuntimeError(f"Zip missing.")
    else: display(Markdown("⚠️ Extraction skipped (no zip)."))
else:
    try: 
        extract_zip(zip_file_path, extracted_videos_path)
        # Move all videos to main directory
        move_videos_to_main_directory(extracted_videos_path)
        display(Markdown(f"✅ Extracted to `{extracted_videos_path}` and moved all videos to main directory."))
    except Exception as e:
        display(Markdown(f"❌ **Extraction Error:** {e}."))
        if not SKIP_PREPARE: raise RuntimeError("Extraction failed.")
        else: display(Markdown("⚠️ Extraction failed, skipping prep."))
# Out:
# ### Extracting Archive
# ✅ Skipping extraction: Files in `extracted_videos`.

# %% [markdown]
# ### Slow/Speed Up Videos
# Losslessly change video speed while also re-encoding audio to maintain pitch. As
# a result, is super fast. Could be made faster if using asyncio to concurrently run
# ffmpeg.

# %%
async def run_subprocess(cmd, check=True, capture_output=False):
    """Helper function to run subprocess asynchronously."""
    stdout_pipe = asyncio.subprocess.PIPE if capture_output else asyncio.subprocess.DEVNULL
    # Capture stderr only if check is True or capture_output is True, otherwise DEVNULL
    stderr_pipe = asyncio.subprocess.PIPE if check or capture_output else asyncio.subprocess.DEVNULL

    process = await asyncio.create_subprocess_exec(
        *cmd,
        stdout=stdout_pipe,
        stderr=stderr_pipe
    )
    stdout, stderr = await process.communicate()

    if check and process.returncode != 0:
        error_msg = f"Command '{' '.join(cmd)}' failed with return code {process.returncode}"
        stderr_decoded = stderr.decode(errors='ignore') if stderr else ""
        if stderr_decoded:
            error_msg += f"\nStderr: {stderr_decoded}"
        # Raise specific exception to potentially capture stderr later
        raise subprocess.CalledProcessError(process.returncode, cmd, output=stdout, stderr=stderr)

    return stdout, stderr, process.returncode

async def process_single_video(vid_path, speed_videos_path, VIDEO_SPEED_FACTOR, semaphore):
    """Asynchronously processes a single video. Returns status string."""
    vid_path_str = str(vid_path.resolve())
    out_path = speed_videos_path / vid_path.name
    out_path_str = str(out_path.resolve())

    async with semaphore: # Limit concurrency
        if out_path.is_file():
            return 'skipped'

        if VIDEO_SPEED_FACTOR == 1.0:
            try:
                # Use asyncio.to_thread for potentially blocking I/O
                await asyncio.to_thread(shutil.copy, vid_path_str, out_path_str)
                return 'processed'
            except Exception as e:
                try:
                    logger.error(f"Error copying {vid_path.name}: {e}")
                except NameError:
                    print(f"Error copying {vid_path.name}: {e}")
                return 'error'

        # --- Process video with speed change ---
        tf_bitstream_path = None
        tf_audio_path = None
        tf_final_path = None
        try:
            # Create temporary files (synchronous part is okay here)
            # Context manager ensures files are closed before ffmpeg uses them
            with tempfile.NamedTemporaryFile(delete=False, suffix=".h264") as tf_b, \
                 tempfile.NamedTemporaryFile(delete=False, suffix=".aac") as tf_a, \
                 tempfile.NamedTemporaryFile(delete=False, suffix=".mp4") as tf_f:
                tf_bitstream_name = tf_b.name
                tf_audio_name = tf_a.name
                tf_final_name = tf_f.name
            # Store paths for cleanup
            tf_bitstream_path = Path(tf_bitstream_name)
            tf_audio_path = Path(tf_audio_name)
            tf_final_path = Path(tf_final_name)


            # Get original FPS
            ffprobe_cmd = [
                "ffprobe", "-v", "error", "-select_streams", "v", "-of", "default=noprint_wrappers=1:nokey=1",
                "-show_entries", "stream=r_frame_rate", vid_path_str
            ]
            stdout, _, _ = await run_subprocess(ffprobe_cmd, check=True, capture_output=True)
            fps = float(fractions.Fraction(stdout.decode().strip()))
            new_fps = fps * VIDEO_SPEED_FACTOR

            # Extract and speed up audio
            factor = VIDEO_SPEED_FACTOR
            filter_parts = []
            while factor > 2.0:
                filter_parts.append("atempo=2.0")
                factor /= 2.0
            while factor < 0.5:
                filter_parts.append("atempo=0.5")
                factor /= 0.5
            if abs(factor - 1.0) > 1e-6:
                 filter_parts.append(f"atempo={factor:.6f}")

            if not filter_parts:
                 audio_cmd = ["ffmpeg", "-y", "-i", vid_path_str, "-vn", "-c:a", "copy", tf_audio_name]
            else:
                audio_filter = ",".join(filter_parts)
                audio_cmd = ["ffmpeg", "-y", "-i", vid_path_str, "-vn", "-filter:a", audio_filter, "-c:a", "aac", "-b:a", "128k", tf_audio_name]
            await run_subprocess(audio_cmd, check=True)


            # Extract h264 bitstream
            extract_cmd = ["ffmpeg", "-y", "-i", vid_path_str, "-map", "0:v", "-c:v", "copy", "-bsf:v", "h264_mp4toannexb", tf_bitstream_name]
            await run_subprocess(extract_cmd, check=True)

            # Remux bitstream with new audio and FPS
            remux_cmd = ["ffmpeg", "-y", "-fflags", "+genpts", "-r", f"{new_fps:.6f}", "-i", tf_bitstream_name, "-i", tf_audio_name, "-map", "0:v", "-map", "1:a", "-c:v", "copy", "-c:a", "copy", tf_final_name]
            await run_subprocess(remux_cmd, check=True)

            # Move final file (use asyncio.to_thread)
            await asyncio.to_thread(shutil.move, tf_final_name, out_path_str)
            return 'processed'

        except Exception as e:
            err_msg = f"Error processing {vid_path.name}: {e}"
            # Include ffmpeg stderr if available
            if isinstance(e, subprocess.CalledProcessError) and e.stderr:
                 err_msg += f"\nFFmpeg/FFprobe Stderr:\n{e.stderr.decode(errors='ignore')}"
            try:
                logger.error(err_msg)
            except NameError:
                print(err_msg)
            return 'error'
        finally:
            # Clean up temporary files asynchronously using to_thread
            async def _cleanup():
                if tf_bitstream_path and tf_bitstream_path.exists():
                    tf_bitstream_path.unlink(missing_ok=True)
                if tf_audio_path and tf_audio_path.exists():
                    tf_audio_path.unlink(missing_ok=True)
                # tf_final is moved, only delete if error occurred before move
                if tf_final_path and tf_final_path.exists():
                    tf_final_path.unlink(missing_ok=True)
            # Run sync cleanup in thread only if paths were assigned
            if tf_bitstream_path or tf_audio_path or tf_final_path:
                 await asyncio.to_thread(_cleanup)


# --- Main Cell Logic ---

async def run_processing(): # Wrap in an async function to use await
    display(Markdown("### Preparing Videos"))
    if dataset_df is None:
        raise RuntimeError("Dataset DF unavailable.")

    # Ensure output directory exists
    speed_videos_path.mkdir(parents=True, exist_ok=True)

    all_video_ids = sorted(list(dataset_df['video_id'].dropna().unique()))
    # Use logging if available, otherwise print
    try:
        logger.info(f"Processing {len(all_video_ids)} unique video IDs.")
    except NameError:
        print(f"Processing {len(all_video_ids)} unique video IDs.")

    vid_paths = list(extracted_videos_path.glob("*.mp4"))

    # Limit concurrency
    concurrency_limit = MAX_ASYNC_WORKERS
    try:
        logger.info(f"Using concurrency limit: {concurrency_limit}")
    except NameError:
        print(f"Using concurrency limit: {concurrency_limit}")
    semaphore = asyncio.Semaphore(concurrency_limit)

    tasks = []
    # Keep the familiar loop structure for creating tasks
    print(f"Preparing tasks for {len(vid_paths)} videos...")
    for vid_path in vid_paths:
         # Create a task for each video processing job
         # Pass necessary arguments to the task creator
         task = asyncio.create_task(process_single_video(vid_path, speed_videos_path, VIDEO_SPEED_FACTOR, semaphore))
         tasks.append(task)

    # Now, run all the created tasks concurrently and display progress
    # Use asyncio.as_completed with a standard tqdm progress bar
    print(f"Transforming {len(tasks)} Videos...")
    results = []
    # Use the imported tqdm (now tqdm.auto) to create a standard progress bar instance
    with tqdm(total=len(tasks), desc="Transforming Videos", unit="video") as pbar:
        for future in asyncio.as_completed(tasks):
            try:
                result = await future # Get result from completed task
                results.append(result)
            except Exception as exc:
                # Log errors from tasks that failed internally if not caught by process_single_video
                # (process_single_video should ideally return 'error' status instead of raising)
                try:
                    logger.error(f"Task for a video failed: {exc}")
                except NameError:
                    print(f"Task for a video failed: {exc}")
                results.append('error') # Count as error if task itself fails unexpectedly
            finally:
                 pbar.update(1) # Increment progress bar regardless of outcome


    # Count results
    processed = results.count('processed')
    skipped = results.count('skipped')
    errors = results.count('error')

    print(f"\n\n{skipped} videos skipped, {processed} videos processed, {errors} errors, {len(vid_paths)} total.")

# --- Execute the async processing ---
# In a Jupyter Notebook, you usually need to await the top-level async function.
# If top-level await isn't enabled, you might need nest_asyncio or run manually.
# Using await directly is the most common way in modern notebooks.
await run_processing()
# Out:
# ### Preparing Videos
# 2025-04-24 03:14:06,581 - INFO - Processing 289 unique video IDs.
# 2025-04-24 03:14:06,582 - INFO - Using concurrency limit: 40
# Preparing tasks for 289 videos...
# Transforming 289 Videos...
# Transforming Videos:   0%|          | 0/289 [00:00<?, ?video/s]
# 289 videos skipped, 0 videos processed, 0 errors, 289 total.

# %% [markdown]
# ### Preparing and Upload Videos to GCS or File API

# %%
# --- Prepare Videos (Upload GCS/File API) & Update Metadata --- #
#-- Can set SKIP_PREPARE to True to skip this step if you already uploaded it into bucket through Vertex AI Mode/ into files through Gemini API key --#
display(Markdown("### Preparing Videos & Updating Metadata"))
if SKIP_PREPARE:
    display(Markdown("✅ Skipping video preparation."))
elif storage_client is None:
     display(Markdown("❌ Cannot prepare: Client not ready.")); raise RuntimeError("Client missing.")
else:
    if dataset_df is None: raise RuntimeError("Dataset DF unavailable.")
    all_video_ids = sorted(list(dataset_df['video_id'].dropna().unique()))
    logger.info(f"Processing {len(all_video_ids)} unique video IDs.")

    videos_to_process_ids = all_video_ids
    if MAX_VIDEOS_TO_PROCESS is not None:
        videos_to_process_ids = all_video_ids[:MAX_VIDEOS_TO_PROCESS]
        logger.info(f"Limiting to {len(videos_to_process_ids)} videos.")

    # Load existing metadata to check status
    existing_statuses = {}
    resource_ids = {}
    required_id_col = 'gcs_uri' if USE_VERTEX else 'file_api_name'
    if Path(METADATA_FILE).is_file():
        try:
            existing_df = pd.read_csv(METADATA_FILE, dtype=str)
            if 'video_id' in existing_df.columns and 'status' in existing_df.columns:
                existing_statuses = pd.Series(existing_df.status.values, index=existing_df.video_id).to_dict()
            if 'video_id' in existing_df.columns and required_id_col in existing_df.columns:
                 resource_ids = pd.Series(existing_df[required_id_col].values, index=existing_df.video_id).dropna().to_dict()
            logger.info("Checked existing metadata statuses/IDs.")
        except Exception as e: logger.warning(f"Could not load existing metadata: {e}")

    video_metadata_updates = {}
    processed_count, upload_failures, missing_local, skipped_count = 0, 0, 0, 0
    num_batches = math.ceil(len(videos_to_process_ids) / UPLOAD_BATCH_SIZE_GCS)
    prep_mode = "GCS Upload" if USE_VERTEX else "File API Upload"

    with tqdm(total=len(videos_to_process_ids), desc=f"Preparing ({prep_mode})") as pbar:
        for i in range(0, len(videos_to_process_ids), UPLOAD_BATCH_SIZE_GCS):
            batch_ids = videos_to_process_ids[i : i + UPLOAD_BATCH_SIZE_GCS]
            batch_num = (i // UPLOAD_BATCH_SIZE_GCS) + 1
            logger.info(f"Prep Batch {batch_num}/{num_batches}...")
            current_batch_updates = {}

            for video_id in batch_ids:
                pbar.set_postfix_str(f"ID: {video_id}")
                update_data = {"local_path": None, "gcs_uri": None, "file_api_name": None, "status": "error_unknown"}
                local_video_path = speed_videos_path / f"{video_id}.mp4"
                current_status = existing_statuses.get(video_id, 'pending')
                existing_resource_id = resource_ids.get(video_id)
                is_already_processed = False

                # Check if already uploaded and verified
                if current_status in ['uploaded_gcs', 'uploaded_file_api'] and existing_resource_id:
                     verified = False
                     if USE_VERTEX: verified = verify_gcs_file_exists(storage_client, existing_resource_id)
                     else: verified = verify_file_api_resource_exists(storage_client, existing_resource_id)
                     if verified:
                         logger.debug(f"Skipping verified video {video_id} ('{current_status}').")
                         is_already_processed = True
                         skipped_count += 1
                         update_data.update({ # Ensure metadata is consistent
                             'local_path': str(local_video_path) if local_video_path.is_file() else None,
                             'status': current_status,
                             required_id_col: existing_resource_id
                         })
                     else:
                         logger.warning(f"Video {video_id} ({current_status}) needs re-processing (verification failed).")
                elif current_status != 'pending':
                     logger.debug(f"Video {video_id} has non-pending status '{current_status}' but no verified resource ID. Re-processing.")

                if is_already_processed:
                    processed_count += 1
                    current_batch_updates[video_id] = update_data
                    pbar.update(1)
                    continue

                # Process if needed
                if local_video_path.is_file():
                    update_data["local_path"] = str(local_video_path)
                    resource_id_result = None
                    if USE_VERTEX:
                        blob_name = f"videos/{video_id}.mp4"
                        resource_id_result = upload_to_gcs(storage_client, GCS_BUCKET, local_video_path, blob_name)
                        if resource_id_result: update_data.update({"gcs_uri": resource_id_result, "status": "uploaded_gcs"})
                        else: update_data["status"] = "gcs_upload_failed"; upload_failures += 1
                    else: # Gemini API
                        resource_id_result = upload_via_file_api(storage_client, local_video_path, f"vid_{video_id}")
                        if resource_id_result: update_data.update({"file_api_name": resource_id_result, "status": "uploaded_file_api"})
                        else: update_data["status"] = "file_api_upload_failed"; upload_failures += 1
                else:
                    logger.warning(f"Local file missing: {local_video_path}")
                    missing_local += 1
                    update_data["status"] = "local_missing"

                current_batch_updates[video_id] = update_data
                processed_count += 1
                pbar.update(1)

            # Update metadata after batch
            if current_batch_updates:
                 try: create_or_update_metadata(METADATA_FILE, dataset_df, current_batch_updates)
                 except Exception as e: logger.error(f"Metadata update failed batch {batch_num}: {e}")
                 video_metadata_updates.update(current_batch_updates)

    logger.info(f"Prep finished. Checked: {processed_count}, Skipped(verified): {skipped_count}, Missing Local: {missing_local}, Upload Failures: {upload_failures}")
    display(Markdown(f"✅ Video preparation complete. See logs. Metadata: `{METADATA_FILE}`."))
# Out:
# ### Preparing Videos & Updating Metadata
# 2025-04-24 03:14:06,653 - INFO - Processing 289 unique video IDs.
# 2025-04-24 03:14:06,663 - INFO - Checked existing metadata statuses/IDs.
# Preparing (File API Upload):   0%|          | 0/289 [00:00<?, ?it/s]
# 2025-04-24 03:14:06,668 - INFO - Prep Batch 1/29...
# 2025-04-24 03:14:06,917 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/og0a6do1tpwp "HTTP/1.1 200 OK"
# 2025-04-24 03:14:07,904 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/18o7oiqwp1m4 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:08,150 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/nwd6dcssxn5g "HTTP/1.1 200 OK"
# 2025-04-24 03:14:09,138 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5rugpm724dos "HTTP/1.1 200 OK"
# 2025-04-24 03:14:09,376 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uv6xrrdirs62 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:10,370 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2uvktznt7pa6 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:10,614 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9rzil2rzalbo "HTTP/1.1 200 OK"
# 2025-04-24 03:14:10,853 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lrec84l6s07n "HTTP/1.1 200 OK"
# 2025-04-24 03:14:11,095 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ioxhwrde8skh "HTTP/1.1 200 OK"
# 2025-04-24 03:14:11,332 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ko00ccpxm62x "HTTP/1.1 200 OK"
# 2025-04-24 03:14:11,357 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:11,358 - INFO - Prep Batch 2/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:11,592 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lpjysj4nfk2j "HTTP/1.1 200 OK"
# 2025-04-24 03:14:11,835 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rn3qhuqto9x2 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:12,071 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zrjs3cwo111w "HTTP/1.1 200 OK"
# 2025-04-24 03:14:12,306 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3xat2tk0x5ou "HTTP/1.1 200 OK"
# 2025-04-24 03:14:12,544 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/20dv3z6af9zz "HTTP/1.1 200 OK"
# 2025-04-24 03:14:12,784 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/cvb9esfjtt6c "HTTP/1.1 200 OK"
# 2025-04-24 03:14:13,014 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/cum701k1eq5e "HTTP/1.1 200 OK"
# 2025-04-24 03:14:13,256 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hh6veynb0168 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:13,508 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/r3ujaacv9yty "HTTP/1.1 200 OK"
# 2025-04-24 03:14:13,743 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/80mvibtw4t4w "HTTP/1.1 200 OK"
# 2025-04-24 03:14:13,767 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:13,768 - INFO - Prep Batch 3/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:13,995 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/edigwvqw9av9 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:14,230 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/w6mpz5ghecx "HTTP/1.1 200 OK"
# 2025-04-24 03:14:14,470 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uubrz6yx11kr "HTTP/1.1 200 OK"
# 2025-04-24 03:14:14,712 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/41cjipgnj7qx "HTTP/1.1 200 OK"
# 2025-04-24 03:14:14,941 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/s4p21njekab1 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:15,179 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5izcnmjnqq1l "HTTP/1.1 200 OK"
# 2025-04-24 03:14:15,415 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/pjjgf7883z4 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:15,644 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/azigff5lep8c "HTTP/1.1 200 OK"
# 2025-04-24 03:14:15,880 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/a0eazum7b7xf "HTTP/1.1 200 OK"
# 2025-04-24 03:14:16,116 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jyant3te87j7 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:16,141 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:16,142 - INFO - Prep Batch 4/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:16,378 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/g6q7aifdwv4g "HTTP/1.1 200 OK"
# 2025-04-24 03:14:16,636 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xwt72aglcv57 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:16,875 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/f6rtxz6omw09 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:17,124 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5angqwlkl9r0 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:17,368 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1w1strhwfrxk "HTTP/1.1 200 OK"
# 2025-04-24 03:14:17,595 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/i481ikq7ot66 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:17,834 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/67d8iijtb2za "HTTP/1.1 200 OK"
# 2025-04-24 03:14:18,068 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6d6t5zp7oxwk "HTTP/1.1 200 OK"
# 2025-04-24 03:14:18,299 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hjswx7s5f31o "HTTP/1.1 200 OK"
# 2025-04-24 03:14:18,531 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2ueul0q4gynz "HTTP/1.1 200 OK"
# 2025-04-24 03:14:18,555 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:18,555 - INFO - Prep Batch 5/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:18,783 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ax94noo6ktgp "HTTP/1.1 200 OK"
# 2025-04-24 03:14:19,028 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/aui3e5ophi7k "HTTP/1.1 200 OK"
# 2025-04-24 03:14:19,268 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zyncqyb7zs39 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:19,521 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/j0zyodjypu6y "HTTP/1.1 200 OK"
# 2025-04-24 03:14:19,749 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/749ns7wd08mj "HTTP/1.1 200 OK"
# 2025-04-24 03:14:19,986 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/c01t64ksxcsf "HTTP/1.1 200 OK"
# 2025-04-24 03:14:20,228 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ta2hl1tmh1yu "HTTP/1.1 200 OK"
# 2025-04-24 03:14:20,474 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xq81xiqhv3wh "HTTP/1.1 200 OK"
# 2025-04-24 03:14:20,728 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xybbitfjbxod "HTTP/1.1 200 OK"
# 2025-04-24 03:14:20,964 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/trmd0vqz056b "HTTP/1.1 200 OK"
# 2025-04-24 03:14:20,987 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:20,988 - INFO - Prep Batch 6/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:21,218 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/l5bez9tkslkn "HTTP/1.1 200 OK"
# 2025-04-24 03:14:21,452 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/juzenky80gnx "HTTP/1.1 200 OK"
# 2025-04-24 03:14:21,683 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/x4e7940m2w6y "HTTP/1.1 200 OK"
# 2025-04-24 03:14:21,918 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qgdi14i3nyc "HTTP/1.1 200 OK"
# 2025-04-24 03:14:22,159 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/isv1d80wasnj "HTTP/1.1 200 OK"
# 2025-04-24 03:14:22,410 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/64a62jztada2 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:22,648 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6cfe5hg6snoo "HTTP/1.1 200 OK"
# 2025-04-24 03:14:22,886 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/dvt3el3xyr31 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:23,124 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1udwk3hr54n0 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:23,363 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ue72mq5mpijm "HTTP/1.1 200 OK"
# 2025-04-24 03:14:23,387 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:23,388 - INFO - Prep Batch 7/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:23,630 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ff9jigeowz45 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:23,865 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/mr1613eza0xe "HTTP/1.1 200 OK"
# 2025-04-24 03:14:24,099 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/mpgt10hc8lch "HTTP/1.1 200 OK"
# 2025-04-24 03:14:24,364 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jdk6x0262403 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:24,593 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gvjwjlipxjur "HTTP/1.1 200 OK"
# 2025-04-24 03:14:24,836 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/l9sni81jwnmf "HTTP/1.1 200 OK"
# 2025-04-24 03:14:25,081 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5d7lmp57wrz6 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:25,312 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/aqqjtwuavfvn "HTTP/1.1 200 OK"
# 2025-04-24 03:14:25,541 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7lut2z0u06kt "HTTP/1.1 200 OK"
# 2025-04-24 03:14:25,771 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/do5el3o6v5uw "HTTP/1.1 200 OK"
# 2025-04-24 03:14:25,795 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:25,795 - INFO - Prep Batch 8/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:26,040 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/moyq9z0ymp93 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:26,287 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/nw540f1nn5q5 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:26,518 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/kdozm0rby5su "HTTP/1.1 200 OK"
# 2025-04-24 03:14:26,756 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/f07n3xut2u8i "HTTP/1.1 200 OK"
# 2025-04-24 03:14:26,994 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lfw5qaix3onf "HTTP/1.1 200 OK"
# 2025-04-24 03:14:27,229 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/44nynnhxiwfa "HTTP/1.1 200 OK"
# 2025-04-24 03:14:27,458 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/sz9q0h8pfupe "HTTP/1.1 200 OK"
# 2025-04-24 03:14:27,695 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vscwbpk1454v "HTTP/1.1 200 OK"
# 2025-04-24 03:14:27,935 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/k6krfmuu1lvd "HTTP/1.1 200 OK"
# 2025-04-24 03:14:28,168 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/whwo06x25gsb "HTTP/1.1 200 OK"
# 2025-04-24 03:14:28,192 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:28,193 - INFO - Prep Batch 9/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:28,435 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vkxvscus9rxk "HTTP/1.1 200 OK"
# 2025-04-24 03:14:28,673 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ssqb0wt6ep1k "HTTP/1.1 200 OK"
# 2025-04-24 03:14:28,908 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/guvw073sa871 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:29,156 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/s06001cxl1nt "HTTP/1.1 200 OK"
# 2025-04-24 03:14:29,394 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xpt9rnzz4hnv "HTTP/1.1 200 OK"
# 2025-04-24 03:14:29,629 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hjj4wckl6jtt "HTTP/1.1 200 OK"
# 2025-04-24 03:14:29,870 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9ygsugwxj24a "HTTP/1.1 200 OK"
# 2025-04-24 03:14:30,109 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/unxpbz9n2cqc "HTTP/1.1 200 OK"
# 2025-04-24 03:14:30,352 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/u91mai4wcjoz "HTTP/1.1 200 OK"
# 2025-04-24 03:14:30,593 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8imezzkt9wlq "HTTP/1.1 200 OK"
# 2025-04-24 03:14:30,617 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:30,618 - INFO - Prep Batch 10/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:30,852 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/fgwzyxbdimtz "HTTP/1.1 200 OK"
# 2025-04-24 03:14:31,093 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/krth2law0nlv "HTTP/1.1 200 OK"
# 2025-04-24 03:14:31,328 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6m0dsvyflwha "HTTP/1.1 200 OK"
# 2025-04-24 03:14:31,577 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2fwyvt5603kp "HTTP/1.1 200 OK"
# 2025-04-24 03:14:31,818 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/cuivj7thi5n1 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:32,053 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3ipes8iguz2h "HTTP/1.1 200 OK"
# 2025-04-24 03:14:32,287 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jl2sphmalzx2 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:32,512 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/e6t8slx8riiz "HTTP/1.1 200 OK"
# 2025-04-24 03:14:32,749 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/k5ha8vgedszx "HTTP/1.1 200 OK"
# 2025-04-24 03:14:32,985 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2kg2i2hppc8m "HTTP/1.1 200 OK"
# 2025-04-24 03:14:33,009 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:33,009 - INFO - Prep Batch 11/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:33,244 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/fbcid9zo6wcp "HTTP/1.1 200 OK"
# 2025-04-24 03:14:33,493 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5fw473mcgg91 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:33,729 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7gqdsyn1umib "HTTP/1.1 200 OK"
# 2025-04-24 03:14:33,976 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/f34stx7asnvf "HTTP/1.1 200 OK"
# 2025-04-24 03:14:34,210 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jtp2ynggrq5o "HTTP/1.1 200 OK"
# 2025-04-24 03:14:34,446 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/fiagw3pnl1wv "HTTP/1.1 200 OK"
# 2025-04-24 03:14:34,694 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5ptja9ygcguo "HTTP/1.1 200 OK"
# 2025-04-24 03:14:34,935 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/44eur1up6ufq "HTTP/1.1 200 OK"
# 2025-04-24 03:14:35,212 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/58bkskeo2ajx "HTTP/1.1 200 OK"
# 2025-04-24 03:14:35,450 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/kr6ul02vn0by "HTTP/1.1 200 OK"
# 2025-04-24 03:14:35,473 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:35,474 - INFO - Prep Batch 12/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:35,707 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ybfidik6de7d "HTTP/1.1 200 OK"
# 2025-04-24 03:14:35,941 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qsv79zfg8lwd "HTTP/1.1 200 OK"
# 2025-04-24 03:14:36,174 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ui4431gcskzf "HTTP/1.1 200 OK"
# 2025-04-24 03:14:36,410 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/elaqlfnpas3d "HTTP/1.1 200 OK"
# 2025-04-24 03:14:36,658 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/e3v1w5c7i3k7 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:36,926 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7kp6z721jm58 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:37,159 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lzse7xbbutqu "HTTP/1.1 200 OK"
# 2025-04-24 03:14:37,415 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/fmtb60c1pz1z "HTTP/1.1 200 OK"
# 2025-04-24 03:14:37,661 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/bferbuit0wwv "HTTP/1.1 200 OK"
# 2025-04-24 03:14:37,905 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gkhwyoajxzrm "HTTP/1.1 200 OK"
# 2025-04-24 03:14:37,929 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:37,930 - INFO - Prep Batch 13/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:38,163 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/de2pc5yot9g9 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:38,388 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zc9v2ifp4h6s "HTTP/1.1 200 OK"
# 2025-04-24 03:14:38,625 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/81dv0ka2ztyl "HTTP/1.1 200 OK"
# 2025-04-24 03:14:38,869 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jx2judq7lv1g "HTTP/1.1 200 OK"
# 2025-04-24 03:14:39,101 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zeku67m0zywe "HTTP/1.1 200 OK"
# 2025-04-24 03:14:39,340 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/64ya6kbr5d43 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:39,579 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/d7irnbhxrldn "HTTP/1.1 200 OK"
# 2025-04-24 03:14:39,813 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qtzs47l75mbf "HTTP/1.1 200 OK"
# 2025-04-24 03:14:40,046 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/x9s9dfk2sqri "HTTP/1.1 200 OK"
# 2025-04-24 03:14:40,283 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ryv8up93798y "HTTP/1.1 200 OK"
# 2025-04-24 03:14:40,306 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:40,307 - INFO - Prep Batch 14/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:40,547 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/viv0bl21q5c4 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:40,809 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1fm9g1exb705 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:41,047 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/sqyc54g7pje7 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:41,283 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/omonipqfw2tb "HTTP/1.1 200 OK"
# 2025-04-24 03:14:41,517 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5qe03y87hoal "HTTP/1.1 200 OK"
# 2025-04-24 03:14:41,747 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/edm4z0qywgp5 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:41,997 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zrp7n7wsoyyp "HTTP/1.1 200 OK"
# 2025-04-24 03:14:42,240 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jqc1yl7k81fa "HTTP/1.1 200 OK"
# 2025-04-24 03:14:42,484 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6isor3br193m "HTTP/1.1 200 OK"
# 2025-04-24 03:14:42,719 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/k4rsg9i9glcc "HTTP/1.1 200 OK"
# 2025-04-24 03:14:42,742 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:42,743 - INFO - Prep Batch 15/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:42,975 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xx457xl75kla "HTTP/1.1 200 OK"
# 2025-04-24 03:14:43,211 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/w7jr2cli9uqj "HTTP/1.1 200 OK"
# 2025-04-24 03:14:43,460 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/v8v6owqzxyg3 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:43,703 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2yx4bm9hzx5n "HTTP/1.1 200 OK"
# 2025-04-24 03:14:43,939 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/h47wxg6qa32j "HTTP/1.1 200 OK"
# 2025-04-24 03:14:44,216 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/dzexelrbd2ar "HTTP/1.1 200 OK"
# 2025-04-24 03:14:44,459 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3cgeyc14cpso "HTTP/1.1 200 OK"
# 2025-04-24 03:14:44,704 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gj7ilyn39v4x "HTTP/1.1 200 OK"
# 2025-04-24 03:14:44,934 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/kvzcyuziv4qp "HTTP/1.1 200 OK"
# 2025-04-24 03:14:45,173 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ohjtxx2pqxrw "HTTP/1.1 200 OK"
# 2025-04-24 03:14:45,200 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:45,200 - INFO - Prep Batch 16/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:45,439 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/aupetd26yrvn "HTTP/1.1 200 OK"
# 2025-04-24 03:14:45,675 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wo9fswzfct76 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:45,907 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/fioxs1p3hif1 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:46,158 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/dkyy96tfp45m "HTTP/1.1 200 OK"
# 2025-04-24 03:14:46,396 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5apkgtn4fhyq "HTTP/1.1 200 OK"
# 2025-04-24 03:14:46,637 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/24a4hlc0d0s5 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:46,878 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/f5moejgkggjp "HTTP/1.1 200 OK"
# 2025-04-24 03:14:47,115 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jlr7wvtr4c7h "HTTP/1.1 200 OK"
# 2025-04-24 03:14:47,356 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/iul9kx33baw8 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:47,592 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/pvkbnethizh2 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:47,616 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:47,616 - INFO - Prep Batch 17/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:47,850 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/kd2lb9gs7e89 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:48,201 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/18ybnazqj7ky "HTTP/1.1 200 OK"
# 2025-04-24 03:14:48,442 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3ronraq7p84r "HTTP/1.1 200 OK"
# 2025-04-24 03:14:48,706 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/28afjdym8lut "HTTP/1.1 200 OK"
# 2025-04-24 03:14:48,943 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8mt3ofwyi54 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:49,178 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3j8n5pyiw7tl "HTTP/1.1 200 OK"
# 2025-04-24 03:14:49,427 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7u9ssd9q06ho "HTTP/1.1 200 OK"
# 2025-04-24 03:14:49,660 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lpmf2p4nuegv "HTTP/1.1 200 OK"
# 2025-04-24 03:14:49,905 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wruum5fwh373 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:50,147 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/u65uigtaaxx7 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:50,173 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:50,174 - INFO - Prep Batch 18/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:50,399 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6h9azggd7ef "HTTP/1.1 200 OK"
# 2025-04-24 03:14:50,637 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/t4wftplvq2lc "HTTP/1.1 200 OK"
# 2025-04-24 03:14:50,875 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3ni1g7ro2l2w "HTTP/1.1 200 OK"
# 2025-04-24 03:14:51,111 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/crnn8mn0j6mt "HTTP/1.1 200 OK"
# 2025-04-24 03:14:51,345 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hzzmez8g7b25 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:51,589 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7pm4forvmshc "HTTP/1.1 200 OK"
# 2025-04-24 03:14:51,823 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jhui0ifm04g6 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:52,055 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3lc1gh99410l "HTTP/1.1 200 OK"
# 2025-04-24 03:14:52,295 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/kezj2s6ptrom "HTTP/1.1 200 OK"
# 2025-04-24 03:14:52,534 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/x7vxyi0vwulh "HTTP/1.1 200 OK"
# 2025-04-24 03:14:52,557 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:52,558 - INFO - Prep Batch 19/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:52,799 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zoumj5vyao2k "HTTP/1.1 200 OK"
# 2025-04-24 03:14:53,038 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/nlxa3i3gdnrp "HTTP/1.1 200 OK"
# 2025-04-24 03:14:53,276 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/770nw6ns9w2e "HTTP/1.1 200 OK"
# 2025-04-24 03:14:53,516 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/r6c67axmqz4y "HTTP/1.1 200 OK"
# 2025-04-24 03:14:53,767 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/o4t3bvlnb9kw "HTTP/1.1 200 OK"
# 2025-04-24 03:14:54,003 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gk5eplklu96z "HTTP/1.1 200 OK"
# 2025-04-24 03:14:54,237 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gzpsycjgi0w1 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:54,476 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hsatfo1ccwkr "HTTP/1.1 200 OK"
# 2025-04-24 03:14:54,716 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uuwsvyn1ljs8 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:55,001 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1mkk3v3nucru "HTTP/1.1 200 OK"
# 2025-04-24 03:14:55,025 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:55,026 - INFO - Prep Batch 20/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:55,271 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hvb2ri4nqtgv "HTTP/1.1 200 OK"
# 2025-04-24 03:14:55,509 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/c1092etjxzea "HTTP/1.1 200 OK"
# 2025-04-24 03:14:55,767 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/27n3ttxfby26 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:56,000 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ptq8rujm6m50 "HTTP/1.1 200 OK"
# 2025-04-24 03:14:56,264 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/z0yeqldowohe "HTTP/1.1 200 OK"
# 2025-04-24 03:14:56,500 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/i5b067g4egyx "HTTP/1.1 200 OK"
# 2025-04-24 03:14:56,734 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/inok5coguibv "HTTP/1.1 200 OK"
# 2025-04-24 03:14:56,967 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9ernvsjitr3j "HTTP/1.1 200 OK"
# 2025-04-24 03:14:57,215 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1qt5teqifutf "HTTP/1.1 200 OK"
# 2025-04-24 03:14:57,449 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/509fd104ip6b "HTTP/1.1 200 OK"
# 2025-04-24 03:14:57,476 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:57,477 - INFO - Prep Batch 21/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:14:57,719 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lfx1ra9ylf5r "HTTP/1.1 200 OK"
# 2025-04-24 03:14:57,959 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/t6qsw18kpkdc "HTTP/1.1 200 OK"
# 2025-04-24 03:14:58,192 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/elnva6u749ud "HTTP/1.1 200 OK"
# 2025-04-24 03:14:58,430 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5zgheweou0ts "HTTP/1.1 200 OK"
# 2025-04-24 03:14:58,677 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/h7p23c64rm6l "HTTP/1.1 200 OK"
# 2025-04-24 03:14:58,918 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/sxj6cth6k62v "HTTP/1.1 200 OK"
# 2025-04-24 03:14:59,154 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/d0l4ocpx1fnp "HTTP/1.1 200 OK"
# 2025-04-24 03:14:59,391 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/scjjo25cnyyn "HTTP/1.1 200 OK"
# 2025-04-24 03:14:59,629 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/mf9roqkt7c4r "HTTP/1.1 200 OK"
# 2025-04-24 03:14:59,867 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/grxfkbxvgv1x "HTTP/1.1 200 OK"
# 2025-04-24 03:14:59,893 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:14:59,894 - INFO - Prep Batch 22/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:15:00,129 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/mxcgnkhaewlx "HTTP/1.1 200 OK"
# 2025-04-24 03:15:00,363 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2ahf7ffvndsn "HTTP/1.1 200 OK"
# 2025-04-24 03:15:00,592 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/v6t4gqef81af "HTTP/1.1 200 OK"
# 2025-04-24 03:15:00,831 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/auf3vycmk135 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:01,063 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/en7jkft3qc97 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:01,292 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4a5e7luohb2e "HTTP/1.1 200 OK"
# 2025-04-24 03:15:01,527 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1yvs34t9k8s8 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:01,781 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/dp4gt6r7b3c0 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:02,017 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/k3fxd3cb6oss "HTTP/1.1 200 OK"
# 2025-04-24 03:15:02,259 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8izmvi3i40vc "HTTP/1.1 200 OK"
# 2025-04-24 03:15:02,283 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:15:02,284 - INFO - Prep Batch 23/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:15:02,510 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/p04rl9zcrohm "HTTP/1.1 200 OK"
# 2025-04-24 03:15:02,750 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2wv1p28ovc3p "HTTP/1.1 200 OK"
# 2025-04-24 03:15:02,985 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/bxg5m5v4isjo "HTTP/1.1 200 OK"
# 2025-04-24 03:15:03,216 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/abxlk2lkk3x2 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:03,451 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7e5e1oz1nh7l "HTTP/1.1 200 OK"
# 2025-04-24 03:15:03,692 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wwgh8qkmcodm "HTTP/1.1 200 OK"
# 2025-04-24 03:15:03,929 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/79lbmywn59je "HTTP/1.1 200 OK"
# 2025-04-24 03:15:04,174 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/pfatx2tkafp7 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:04,412 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/d5fvfaepxfom "HTTP/1.1 200 OK"
# 2025-04-24 03:15:04,647 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7e71samyjned "HTTP/1.1 200 OK"
# 2025-04-24 03:15:04,674 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:15:04,674 - INFO - Prep Batch 24/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:15:04,906 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/j7wyq70r52wl "HTTP/1.1 200 OK"
# 2025-04-24 03:15:05,144 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gsx98w4lqjop "HTTP/1.1 200 OK"
# 2025-04-24 03:15:05,384 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/haxc4mh7159w "HTTP/1.1 200 OK"
# 2025-04-24 03:15:05,623 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ibb4wu1d8brx "HTTP/1.1 200 OK"
# 2025-04-24 03:15:05,864 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/nx4av2hp1naq "HTTP/1.1 200 OK"
# 2025-04-24 03:15:06,106 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/656c2m2cju5k "HTTP/1.1 200 OK"
# 2025-04-24 03:15:06,347 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/l3h1dt75xk8b "HTTP/1.1 200 OK"
# 2025-04-24 03:15:06,577 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wzo92h5i3jci "HTTP/1.1 200 OK"
# 2025-04-24 03:15:06,817 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uk2xrmy21wn5 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:07,066 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/bbefnxjjht7v "HTTP/1.1 200 OK"
# 2025-04-24 03:15:07,093 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:15:07,094 - INFO - Prep Batch 25/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:15:07,334 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/al8tpf053xz5 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:07,574 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/apzkn0sq1f6l "HTTP/1.1 200 OK"
# 2025-04-24 03:15:07,808 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9ctqncrgmef4 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:08,039 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hllkc3gx9c89 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:08,272 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/55yjhjkg2vyu "HTTP/1.1 200 OK"
# 2025-04-24 03:15:08,512 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/92yj10hjgijq "HTTP/1.1 200 OK"
# 2025-04-24 03:15:08,750 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gxp4rxef6l1f "HTTP/1.1 200 OK"
# 2025-04-24 03:15:08,988 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qy284ypl24nm "HTTP/1.1 200 OK"
# 2025-04-24 03:15:09,223 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wtkbiprtvja2 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:09,465 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jmambmwoiz6f "HTTP/1.1 200 OK"
# 2025-04-24 03:15:09,494 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:15:09,495 - INFO - Prep Batch 26/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:15:09,726 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rhoqttkyc9lj "HTTP/1.1 200 OK"
# 2025-04-24 03:15:09,970 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ouf9sfbt8osa "HTTP/1.1 200 OK"
# 2025-04-24 03:15:10,210 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/60jqlomto0sp "HTTP/1.1 200 OK"
# 2025-04-24 03:15:10,439 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vg2lr1485xan "HTTP/1.1 200 OK"
# 2025-04-24 03:15:10,674 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ruv82vo822y8 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:10,907 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ssnesw8v1aja "HTTP/1.1 200 OK"
# 2025-04-24 03:15:11,146 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/62a4c83z240y "HTTP/1.1 200 OK"
# 2025-04-24 03:15:11,384 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lzv50wlqirmh "HTTP/1.1 200 OK"
# 2025-04-24 03:15:11,667 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6cpt7fuvfkrj "HTTP/1.1 200 OK"
# 2025-04-24 03:15:11,939 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/kakd01rarqfx "HTTP/1.1 200 OK"
# 2025-04-24 03:15:11,966 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:15:11,967 - INFO - Prep Batch 27/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:15:12,203 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1xfiwn8zks25 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:12,444 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4p3zx60og2tw "HTTP/1.1 200 OK"
# 2025-04-24 03:15:12,727 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/z1utf9rbn55e "HTTP/1.1 200 OK"
# 2025-04-24 03:15:12,964 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ty274jujpbvx "HTTP/1.1 200 OK"
# 2025-04-24 03:15:13,211 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5mzo60pt3tsw "HTTP/1.1 200 OK"
# 2025-04-24 03:15:13,442 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qaftc0hm2rf3 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:13,681 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/t266onrqweg9 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:13,927 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/x4z4g29kmmtk "HTTP/1.1 200 OK"
# 2025-04-24 03:15:14,176 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6hih509vvorf "HTTP/1.1 200 OK"
# 2025-04-24 03:15:14,414 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/pu1sqmwbhrzq "HTTP/1.1 200 OK"
# 2025-04-24 03:15:14,441 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:15:14,442 - INFO - Prep Batch 28/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:15:14,676 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2t50vifybaha "HTTP/1.1 200 OK"
# 2025-04-24 03:15:14,919 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/tw9ac0npfumg "HTTP/1.1 200 OK"
# 2025-04-24 03:15:15,153 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1td14ht7cwlr "HTTP/1.1 200 OK"
# 2025-04-24 03:15:15,386 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ageb02kiwsjw "HTTP/1.1 200 OK"
# 2025-04-24 03:15:15,631 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/k6e0f9ynvi04 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:15,885 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xusxleowu8hb "HTTP/1.1 200 OK"
# 2025-04-24 03:15:16,133 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vu5ek6x1b86k "HTTP/1.1 200 OK"
# 2025-04-24 03:15:16,373 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/eo4lb4bbbmf5 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:16,619 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/my06g5r7wgmh "HTTP/1.1 200 OK"
# 2025-04-24 03:15:16,859 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/cz4pjhgdkzw1 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:16,883 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 10 video records.
# 2025-04-24 03:15:16,883 - INFO - Prep Batch 29/29...
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# 2025-04-24 03:15:17,118 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wue5cngqnvre "HTTP/1.1 200 OK"
# 2025-04-24 03:15:17,356 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8hzmxlyotttf "HTTP/1.1 200 OK"
# 2025-04-24 03:15:17,583 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2n2io51nh791 "HTTP/1.1 200 OK"
# 2025-04-24 03:15:17,823 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uz5b9csx1u3p "HTTP/1.1 200 OK"
# 2025-04-24 03:15:18,067 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ckki55yyn8dx "HTTP/1.1 200 OK"
# 2025-04-24 03:15:18,310 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/amtkogpt3rxj "HTTP/1.1 200 OK"
# 2025-04-24 03:15:18,551 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/p5cn26d6wodz "HTTP/1.1 200 OK"
# 2025-04-24 03:15:18,796 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ygt4yrgzv10g "HTTP/1.1 200 OK"
# 2025-04-24 03:15:19,038 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/nuqms201zvgh "HTTP/1.1 200 OK"
# 2025-04-24 03:15:19,064 - INFO - Metadata file 'video_metadata_non_vertex_inj_correct_mcq.csv' updated with 9 video records.
# 2025-04-24 03:15:19,065 - INFO - Prep finished. Checked: 289, Skipped(verified): 289, Missing Local: 0, Upload Failures: 0
# /tmp/ipykernel_1025125/1810414007.py:116: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   meta_df[col] = merged_df[update_col_name].fillna(merged_df[col])
# ✅ Video preparation complete. See logs. Metadata: `video_metadata_non_vertex_inj_correct_mcq.csv`.

# %% [markdown]
# # Bulk Inference
# ## (Agentic) (Turn by turn) (Correctly led first / Sort heuristics / no exam) Bulk inference CoCoT reasoning with summary model

# %%
RESULTS_FINAL_DIR = os.path.join(f"all_results/full_inference_CoCoT_heuristics_summary/{MODEL_NAME}", RESULTS_FILE)
os.makedirs(os.path.dirname(RESULTS_FINAL_DIR), exist_ok=True)

# %%
def sort_heuristics(qs: list[dict]) -> list[dict]:
    """
    1) Correctly-led Open-ended Question first
    2) Multiple-choice Question with a Single Correct Answer
    3) All other questions in original order
    4) Finally, “Wrongly-led Open-ended Question”
    """
    correct = []
    mcq = []
    other = []
    wrongly = []

    for q in qs:
        qt = q.get("question_type", "")
        if qt == "Correctly-led Open-ended Question":
            correct.append(q)
        elif qt == "Multiple-choice Question with a Single Correct Answer":
            mcq.append(q)
        elif qt == "Wrongly-led Open-ended Question":
            wrongly.append(q)
        else:
            other.append(q)

    return (
        correct
        + mcq
        + other
        + wrongly
    )

# ──────────────────────────────────────────────────────────────────────────────
# 1⃣  Per‑video coroutine – runs Q‑A‑Q‑A, sending video every turn
# ──────────────────────────────────────────────────────────────────────────────
async def run_chat_for_video(
    video_id: str,
    questions: list[Dict],
    client: Any,
    sem: asyncio.Semaphore,
    rate_limiter: Optional[AsyncRateLimiter],
    out_q: asyncio.Queue
):
    """
    Executes every question for one video sequentially:
    video ▶ Q1 ▶ answer ▶ Q2 ▶ answer …, pushing a result dict per QID.
    Video asset is sent on every turn.
    """
    ordered = sort_heuristics(questions)
    if not ordered:
        return

    # Obtain the binary video asset once
    try:
        first = ordered[0]
        if USE_VERTEX:
            if not first.get("gcs_uri"):
                raise ValueError("Missing GCS URI.")
            video_part = types.Part.from_uri(
                mime_type="video/mp4",
                file_uri=first["gcs_uri"]
            )
        else:
            file_name = first.get("file_api_name")
            if not file_name:
                raise ValueError("Missing File API name.")
            video_part = await client.aio.files.get(name=file_name)
    except Exception as e:
        for q in ordered:
            await out_q.put({
                "qid": q.get("qid", "?"),
                "pred": f"ERROR: Input - {e}",
                "duration": 0,
                "finish_reason": "N/A",
                "status": "Failed (Input)"
            })
        return

    chat_history: list = []

    # Loop over questions; include video_part every turn
    for idx, q in enumerate(ordered, start=1):
        prompt = build_prompt(q)
        user_msg = types.Content(
            role="user",
            parts=[types.Part.from_text(text=prompt)]
        )
        contents = [video_part] + chat_history + [user_msg]

        async with sem:
            if rate_limiter:
                await rate_limiter.acquire()
            start = time.time()
            status, finish_reason, answer_text, summary_answer_text = "Success", "UNKNOWN", "ERROR", "ERROR"
            try:
                rsp = await client.aio.models.generate_content(
                    model=MODEL_NAME,
                    contents=contents,
                    config=CONFIG
                )
                answer_text = rsp.text.strip()
                if answer_text:
                    summary_rsp = await client.aio.models.generate_content(
                        model=QUESTION_MODEL_NAME,
                        contents=[types.Content(role="user", parts=[
                            types.Part.from_text(text=prompt),
                            types.Part.from_text(text=answer_text)])],
                        config=QUESTION_CONFIG
                    )
                    summary_answer_text = summary_rsp.text.strip()
                if rsp.candidates and rsp.candidates[0].finish_reason:
                    finish_reason = rsp.candidates[0].finish_reason.name
            except Exception as e:
                status = "Failed (API)"
                answer_text = f"ERROR: {e}"

        # Queue the outcome
        await out_q.put({
            "qid": q.get("qid", "?"),
            "CoT": answer_text,
            "pred": summary_answer_text,
            "duration": round(time.time() - start, 2),
            "finish_reason": finish_reason,
            "status": status
        })

        # Extend in-memory chat (so next turn has full context, sans reloading video)
        chat_history.extend([
            user_msg,
            types.Content(
                role="model",
                parts=[types.Part.from_text(text=answer_text or "…")]
            )
        ])


# ──────────────────────────────────────────────────────────────────────────────
# 2⃣  CSV writer task – same as before
# ──────────────────────────────────────────────────────────────────────────────
async def results_writer_task(
    queue: asyncio.Queue,
    filename: str,
    batch_size: int = 20,
    max_wait_sec: float = 10.0
):
    fieldnames = ["qid", "pred", "CoT", "status", "duration_sec", "finish_reason"]
    file_exists = Path(filename).is_file()
    buf, last_flush = [], time.monotonic()
    logger.info(f"Writer ➔ {filename}")

    while True:
        try:
            item = await asyncio.wait_for(queue.get(), timeout=max_wait_sec)
            if item is None:
                break
            if isinstance(item, dict):
                item["duration_sec"] = round(item.pop("duration", -1), 2)
                buf.append(item)
            queue.task_done()
        except asyncio.TimeoutError:
            pass
        except Exception as e:
            logger.error(f"Writer queue error: {e}", exc_info=True)
            await asyncio.sleep(1)

        if buf and (len(buf) >= batch_size or
                    time.monotonic() - last_flush >= max_wait_sec):
            try:
                with open(filename, "a", newline="", encoding="utf-8") as f:
                    w = csv.DictWriter(f, fieldnames=fieldnames)
                    if not file_exists:
                        w.writeheader()
                        file_exists = True
                    w.writerows(buf)
                buf.clear()
                last_flush = time.monotonic()
            except Exception as e:
                logger.error(f"CSV write error: {e}", exc_info=True)

    # final flush
    if buf:
        try:
            with open(filename, "a", newline="", encoding="utf-8") as f:
                w = csv.DictWriter(f, fieldnames=fieldnames)
                if not file_exists:
                    w.writeheader()
                w.writerows(buf)
        except Exception as e:
            logger.error(f"Final CSV write error: {e}")
    logger.info("Writer done.")


# ──────────────────────────────────────────────────────────────────────────────
# 3⃣  Main async driver – groups by video_id, runs chat per video
# ──────────────────────────────────────────────────────────────────────────────
async def run_bulk_inference_async():
    if ai_client is None:
        logger.error("AI client not initialised."); return

    video_to_qs = load_metadata_for_inference(METADATA_FILE)
    processed_qids = load_processed_qids(RESULTS_FINAL_DIR)
    uri_key = "gcs_uri" if USE_VERTEX else "file_api_name"

    jobs, skipped = [], 0
    for vid, qs in video_to_qs.items():
        pending = [q for q in qs
                   if q.get("qid") not in processed_qids and q.get(uri_key)]
        if pending:
            jobs.append((vid, pending))
        else:
            skipped += len(qs)

    if not jobs:
        logger.info("🎉 No new questions to process."); return
    logger.info(f"🔄 {len(jobs)} videos queued, {skipped} questions skipped.")

    results_q = asyncio.Queue()
    writer = asyncio.create_task(results_writer_task(results_q, RESULTS_FINAL_DIR))
    sem = asyncio.Semaphore(MAX_ASYNC_WORKERS)
    limiter = (AsyncRateLimiter(rate=REQUESTS_PER_MINUTE, period=60.0, capacity=10)
               if REQUESTS_PER_MINUTE else None)

    tasks = [
        run_chat_for_video(vid, qs, ai_client, sem, limiter, results_q)
        for vid, qs in jobs
    ]

    for fut in tqdm(asyncio.as_completed(tasks),
                    total=len(tasks), desc="Videos"):
        try:
            await fut
        except Exception as e:
            logger.error(f"Video task error: {e}", exc_info=True)

    await results_q.put(None)
    await writer
    logger.info("✅ Bulk inference finished.")


# ──────────────────────────────────────────────────────────────────────────────
# 4⃣  Kick it off
# ──────────────────────────────────────────────────────────────────────────────
print(f"DEBUG: Using METADATA_FILE: {METADATA_FILE}")
print(f"DEBUG: File exists? {Path(METADATA_FILE).is_file()}")
print(f"DEBUG: Using RESULTS_FILE: {RESULTS_FINAL_DIR}")
print(f"DEBUG: File exists? {Path(RESULTS_FINAL_DIR).is_file()}")
asyncio.run(run_bulk_inference_async())
# Out:
# DEBUG: Using METADATA_FILE: video_metadata_non_vertex_inj_correct_mcq.csv
# DEBUG: File exists? True
# DEBUG: Using RESULTS_FILE: all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_noncot_full_inference.csv
# DEBUG: File exists? True
# 2025-04-25 17:56:57,549 - INFO - Loaded 289 videos (1500 questions) with valid IDs for inference.
# 2025-04-25 17:56:57,572 - INFO - Loaded 985 processed QIDs from all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_noncot_full_inference.csv
# 2025-04-25 17:56:57,573 - INFO - 🔄 289 videos queued, 0 questions skipped.
# Videos:   0%|          | 0/289 [00:00<?, ?it/s]
# 2025-04-25 17:56:57,582 - INFO - Writer ➔ all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_noncot_full_inference.csv
# 2025-04-25 17:56:58,863 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8g5ava6fbcme "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,884 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:56:58,900 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/z5aht67pjkiz "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,901 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/64gw5mlokkzc "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,902 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uebo5t27ehac "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,903 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/en75gv2eadao "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,904 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/f0p2ksz0trzh "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,905 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zdsq82gia6kt "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,982 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/w3z8qmj6ea4y "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,984 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2obmq75f76dc "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,985 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/tbx34i4py53w "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,986 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/m9adnewpa1o6 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,987 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rkjl1vd0dvlz "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,988 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/p4b9mzrcd5dl "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,990 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/bhivyv0ojcb5 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,991 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lxh3k9xk48al "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,992 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9ob68s62ciz3 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,993 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3e96y0ig2z0k "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,994 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6ik7e0rn64zn "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,995 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/exo72epxrnm0 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,996 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/bpswofp2jil0 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,997 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uv0hqrni45ei "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,998 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/o5lt934igz1l "HTTP/1.1 200 OK"
# 2025-04-25 17:56:58,999 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1m5ses32ah5z "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,001 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/h52dlb7m5t9p "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,002 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/tc38p47ztlz7 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,003 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/h02tygbomc4d "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,004 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uazqyp1ca0ap "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,005 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gw2ja3smm8sj "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,006 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/tgnpq34sqfqf "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,007 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lw43e6l93h0v "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,008 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2pnu99v4iua3 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,009 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2vtq1zh0or3l "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,010 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lv4t5p5k9tk "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,011 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/m0a5jwmrf9du "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,012 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1udx12i40yrl "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,013 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/pkt6c9alqy9m "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,014 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1xgy8oj6tf1k "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,016 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4y2leubori2g "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,017 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/yggw8ia03dj1 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,018 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9g2pxu8677vx "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,019 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/n5lutlz2cekt "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,020 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4s6ss5lkcuz8 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,021 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/syimd6t76zp2 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,022 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6xnbmhj5tl3h "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,023 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/528dgmxwm89r "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,024 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7l2cz2ne00m2 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,025 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lm7q53xf6080 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,026 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6uj0jyn05qur "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,027 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6trlinzcdwnq "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,028 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jc4doe8vdcpa "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,029 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3u67dofnyyig "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,030 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/sx5fmfx4eiks "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,031 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8k9wh7vxzio2 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,032 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5md3h719l8zk "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,033 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/tfezmd2gvvz2 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,035 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/u73ptiad0zni "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,036 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ab9har4svjk1 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,037 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rjkqt3q1pch9 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,038 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/19gujpfyr5vs "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,039 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6tq5zebawxfd "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,040 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jgkgcovieb2h "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,041 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/g6961vkvuwac "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,042 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/m5gnyqn9mr2h "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,043 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/t1l2wf29b50z "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,045 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/38c5mgazzp11 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,046 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3al4l8ommq4c "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,047 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/t9z9p68m88r7 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,048 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zer94gq1a936 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,050 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/enuh93oi0jc7 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,051 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jg7y5pxjhr8i "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,052 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4mlfqvdjkmrg "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,053 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rc17zdbt041z "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,054 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/cn0e1vpogp7 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,056 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/u758559attzd "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,057 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/dmxwg7rcufz3 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,058 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wrjb3pqbknj2 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,059 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5cqrwtbceqff "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,060 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qwgky97c9low "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,061 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:56:59,075 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:56:59,089 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:56:59,708 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1viidtm4fngv "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,710 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/bxtq52nyha3l "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,711 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/89t1uualvm8r "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,712 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qq9eh0vhd51r "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,713 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/95sxu31a3le5 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,715 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/d5ae5jasc6uj "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,716 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9wwydsev5tdb "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,717 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/camsfouvcsjw "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,719 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4zcowp7cr1d9 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,720 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4fodo2gfn9lm "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,721 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4us3afjo2nh5 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,722 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/n9uwjyy5k93p "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,808 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/namlf77pgqwv "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,816 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/iu58ecavbqoz "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,858 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/k3acyto2zqe8 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,864 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/sfgyhjihf6zp "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,876 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/dn5dt81e5wh4 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,877 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qu6b31uqx8c9 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,878 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8rcbd8m832b0 "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,894 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xtuin1ehojpc "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,915 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5o6uq2jk4yjx "HTTP/1.1 200 OK"
# 2025-04-25 17:56:59,916 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/oewyb3iifsyk "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,182 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hy5kadxotwyv "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,292 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/i4vesv1dazvm "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,305 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/it9oyd3fpkrr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,307 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/185fmewd58l6 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,323 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zn5aql0yumjy "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,324 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/mik7j5bkk5wh "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,326 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1cplad97tap0 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,327 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ju9k6llm7eag "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,328 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vh16vlhn4b3x "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,330 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6l0egl8o4bje "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,331 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/twqvidaipjs6 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,332 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/pbabkcbnd48f "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,334 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/x9clap3xbj9j "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,335 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/b7osf6lnuoni "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,336 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qxfgkdvbw3pq "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,337 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rvbobp5zl5c9 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,338 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2lpgx02ehn3e "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,340 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2v6humepan77 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,341 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/f3cx3wu232hs "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,342 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vaw4yp1z6wqy "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,343 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gtrf7erxzrm0 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,344 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/54paqb8zqout "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,345 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/n3t36rn7xi4u "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,347 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/v6drailaoq5v "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,348 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hsin2ichf6ld "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,349 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/aw89hp0rlwz4 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,350 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/in66mw3q4exv "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,351 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/g8cifqq6q3m7 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,352 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/68eslr8mzo1k "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,353 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qnnl2gc33r8u "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,354 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1dgx4iy5johz "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,355 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ig67tfgeul80 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,497 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/axml45bt1trx "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,498 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/p0wj1jenm575 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,499 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wbvpmx5djb9i "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,501 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/bsorsmnarf4j "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,502 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/mq1559ct7b93 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,503 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wd77cceuyu40 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,504 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/475x4xxvp34p "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,506 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7qqzjzca7ndr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,507 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jewa8fbqjx5w "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,508 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/kbvkp5xwmwqb "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,551 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rvcblcz3yb5j "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,553 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/y83zds3x9e2p "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,555 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/c6xv98m3o762 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,556 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/nsukerkuqct "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,557 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9n49r2yjvvjm "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,558 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/mcqhebosiipq "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,559 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ydirv0f5awoz "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,560 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/o037l35fj27d "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,561 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/npqy83em8i5z "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,562 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/o9r2e5ronvm5 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,563 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3i990x7wgnpo "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,564 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/nb6is32zk3p9 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,565 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/c6ctvif4oug1 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,566 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/n77hdnago8bd "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,568 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gic2zep3bcr1 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,569 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/50roglm7htnx "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,570 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1yoj2tj08tmm "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,571 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/v5bwha5y5yxf "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,572 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3rqlwc43tnwj "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,574 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/318e1e8k4cp6 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,575 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/iqumigv6wgrs "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,576 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/pjxwg9onte8t "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,577 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/879y1tn0rlrw "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,578 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/dog59pxd1zt0 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,579 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/e7nzorqgzal4 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,580 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3r4tvi2ncjvu "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,581 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uhdmsmwz1d7f "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,582 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3b5m2fxndrr4 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,583 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/a438w4cja44b "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,585 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4jfo56g69t30 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,586 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4vx8ew5o8qox "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,587 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1kpexblpin4f "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,588 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/y0lnwl1utuea "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,589 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/23u870xvcpsr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,590 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jxgbo5qxzdue "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,591 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/q1t7bztbv7gn "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,592 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/kyyesgpdx0u "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,593 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/j3hcuy8z3tko "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,594 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7mp20qg66p1s "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,596 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hjz2uenlhu98 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,596 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/m8gqlktwtdye "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,598 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zn2v19gcydl3 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,599 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9otwr2sxaj04 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,600 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/438cxd56y2ms "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,601 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/yza2i60kmsi2 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,602 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zzfjusi6p9jc "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,603 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vr7kn1s6ka6p "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,604 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1t9y464lzwe0 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:00,689 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/b62ls0pxt82t "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,041 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/757oxdoho37q "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,046 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6ygwyqer820h "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,069 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/owi04clfg0d5 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,072 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/whq321t7cna7 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,073 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/2e6yyg89zlx "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,077 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/mgvwz9gkd34j "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,079 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/igqwo0zvpouz "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,082 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/y2hf8g0b3ur5 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,096 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/l3xtdkt3z8jo "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,098 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/w8gcxjgj02w4 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,100 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hycd1e76febu "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,102 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/axk69tbcay42 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,104 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/d51718lc35dk "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,108 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/p53rt5vyy4eq "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,110 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vtzgubuvwb9n "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,111 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uzt2e3asevwn "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,112 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5ky2uasfq9lf "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,113 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1l8uw7j3fh5u "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,117 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/j2yiko6v6sez "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,134 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/wzt290o2qamw "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,137 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8rfsnzhnnzhl "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,139 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/bof9gefxjar2 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,143 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6je2kuemmcax "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,145 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/cugq3h6o4x71 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,147 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/slww3tnsz6wr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,148 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xl9an7l9bacq "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,149 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xr1t6u0iq5ap "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,150 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/kmm60trzlz35 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,151 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/nrst02cdhb4r "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,153 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4qjj811nulgr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,156 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rnmj95fyw6u0 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,157 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4zy2x9rkmybr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,159 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rgpek8w0x8ry "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,162 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7ir1u4o34mm7 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,163 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1emfjyvow5rg "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,165 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4ukcqq1ksmxr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,166 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vk2w610wus78 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,167 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9pat4w7686ng "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,169 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/em5lxh1cn7ei "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,170 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/xr89wosdwdew "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,171 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/4xlydh6yol6a "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,172 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/due87rd2pccp "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,174 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/w0v75uy7bzno "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,175 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/b8m0uuug40d7 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,176 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/nxrvul0884bi "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,177 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/pwbj8x4v25qj "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,178 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/24pig69k28lr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,179 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/r7ucvxxl5e3b "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,180 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/6zf7d5o3ma1a "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,181 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jh5jfvvafi2q "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,182 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rdvltt9oyage "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,184 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8sy9br9g09kg "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,185 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9t1ceaxdiygu "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,186 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/g6g3ygrz7feu "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,187 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/qb1dis4g2ijf "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,188 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/x9mhqx9ite7e "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,189 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/7kmhz031oul3 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,190 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/3scfqsaj2it2 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,191 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vanulnnyg0f "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,192 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8hbe2ly06kq0 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,193 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/95vd0uv8wxx1 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,194 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/uo55q5mfj9j3 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,195 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/60spxikzg117 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,196 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/df3tkz6rxlj5 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,197 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/s597xxih2xv2 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,198 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/1la4zatykfd2 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,207 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/dn2476bino4e "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,209 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/deztycvffm6m "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,210 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/g4y2lk2dwkwg "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,211 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/d7w13ikxn8hz "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,213 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/pgvo3zkw8mhr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,220 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/bd2pry2wboa8 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,221 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/u0ynmprko2qg "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,222 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/vb0vhm8sba18 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,224 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/fvyl6492z2o "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,225 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:01,226 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:01,227 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/d18aa1uyy81i "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,231 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/li1hluaruoj9 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,233 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:01,235 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:01,276 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/gwq46i2l235w "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,283 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/s9yw06rghilr "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,286 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/x46zwjjxcuag "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,291 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/5fxbamz38wck "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,293 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/zhlx1s0kuwag "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,306 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/j6ndajgejcwi "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,308 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/8xxot0h10gni "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,311 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/aa61v7qducuf "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,313 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/b860cgdlr8a3 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,316 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/jqsmh2vhd44g "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,324 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:01,325 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:01,332 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/iyszxrte5wbz "HTTP/1.1 200 OK"
# 2025-04-25 17:57:01,525 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:01,527 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:01,531 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:01,533 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:01,597 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:01,600 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:01,798 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:01,805 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:02,060 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/lo61ln1q7g3d "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,076 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/ndmrq4k0n1pc "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,082 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/npmqbegicslg "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,097 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/58eqpisibdvu "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,114 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/9pxs8lm158xo "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,130 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/hd4mhxc3b0ge "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,136 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/rp1ppayniuz5 "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,140 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/t5hd2dik3czo "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,146 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/a7jxawnhh6wj "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,149 - INFO - HTTP Request: GET https://generativelanguage.googleapis.com/v1beta/files/fuffo9t4b93e "HTTP/1.1 200 OK"
# 2025-04-25 17:57:02,329 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:02,566 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:07,461 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:07,726 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:16,036 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:16,324 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:24,608 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:24,926 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:33,179 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:33,465 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:41,752 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:42,053 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:50,322 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:50,620 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:57:58,893 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:57:59,191 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:58:07,465 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:58:07,781 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:58:16,036 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:58:16,342 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:58:24,608 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:58:24,913 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:58:33,180 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:58:33,496 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:58:41,751 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:58:42,078 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:58:50,322 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:58:50,640 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:58:58,894 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:58:59,204 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:59:07,466 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:59:07,773 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:59:16,036 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:59:16,335 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:59:24,609 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:59:24,924 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:59:33,179 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:59:33,487 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 17:59:41,751 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 17:59:42,049 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# ...
# 2025-04-25 19:00:34,434 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:00:41,750 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:00:42,076 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:00:50,322 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:00:50,628 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:00:58,893 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:00:59,195 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:01:07,465 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:01:07,810 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:01:16,036 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:01:16,343 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:01:24,608 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:01:24,928 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:01:33,179 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:01:33,497 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:01:41,750 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:01:43,003 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:01:50,321 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:01:50,625 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:01:58,893 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:01:59,203 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:02:07,465 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:02:08,719 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:02:16,035 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:02:16,345 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:02:24,607 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:02:24,898 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:02:33,179 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:02:34,428 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:02:41,750 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:02:42,049 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:02:50,322 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:02:50,649 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:02:58,894 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:02:59,215 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:03:07,465 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:03:07,763 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:03:16,037 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:03:16,347 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:03:24,608 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:03:24,917 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:03:33,179 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:03:33,508 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:03:41,750 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:03:42,061 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:03:50,322 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:03:50,621 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:03:58,893 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:03:59,198 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:04:07,466 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:04:07,781 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:04:16,036 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:04:16,354 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:04:24,608 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:04:24,923 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:04:33,180 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:04:34,459 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:04:41,751 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:04:42,061 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:04:50,322 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:04:50,635 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:04:58,893 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:04:59,210 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:05:07,465 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:05:07,788 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:05:16,036 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:05:16,341 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:05:24,609 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:05:24,928 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:05:33,179 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:05:33,495 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:05:41,751 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:05:43,020 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:05:50,320 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:05:50,649 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:05:58,895 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:05:59,216 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:06:07,465 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:06:07,754 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:06:16,037 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:06:17,338 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:06:24,607 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:06:24,909 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:06:33,180 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:06:33,505 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:06:41,750 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:06:42,087 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:06:50,322 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:06:51,590 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:06:58,892 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:06:59,193 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:07:07,465 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:07:07,775 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:07:16,036 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:07:16,329 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:07:24,608 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:07:24,916 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:07:33,180 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:07:34,467 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:07:41,749 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:07:42,055 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:07:50,323 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:07:50,626 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:07:58,894 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:07:59,212 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:08:07,465 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:08:07,797 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:08:16,037 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:08:17,324 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:08:24,606 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:08:24,925 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:08:33,179 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:08:34,464 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:08:41,750 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:08:42,421 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:08:50,321 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:08:51,005 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:08:58,894 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:09:00,827 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:09:07,464 - INFO - AFC is enabled with max remote calls: 10.
# 2025-04-25 19:09:08,083 - INFO - HTTP Request: POST https://generativelanguage.googleapis.com/v1beta/models/gemini-2.5-pro-preview-03-25:generateContent "HTTP/1.1 429 Too Many Requests"
# 2025-04-25 19:09:08,091 - INFO - Writer done.
# 2025-04-25 19:09:08,091 - INFO - ✅ Bulk inference finished.

# %% [markdown]
# Check with the clean up again after finishing the Bulk Inference

# %% [markdown]
# ## Interim Up

# %%
def interim_cleanup_and_report():
    """Final cleanup and report of results."""

    try:
        results_df = pd.read_csv(RESULTS_FINAL_DIR, dtype=str)
        logger.info(f"Loaded results from {RESULTS_FINAL_DIR} ({len(results_df)} rows).")
        
        # Correctly identify failed entries
        failed = results_df[results_df['CoT'].isna() | (results_df['status'] != 'Success')]
        
        # Success is everything not in failed
        success = results_df[~results_df.index.isin(failed.index)]

        display(Markdown(f"### Results Summary: {len(success)} Success, {len(failed)} Failed."))

        # Sort by 'qid'
        results_df.sort_values(by=['qid'], inplace=True)

        # remove duplicates based on 'qid' and keep the first occurrence
        results_df.drop_duplicates(subset=['qid'], keep='first', inplace=True)
        logger.info(f"Removed duplicates, remaining {len(results_df)} unique QIDs.")

        # Save the cleaned-up results to a new file with datetime suffix
        original_filename = Path(RESULTS_FINAL_DIR).stem
        # Get the directory of the original file
        original_dir = Path(RESULTS_FINAL_DIR).parent
        # Create the new file names
        success_filename = f"{original_filename}.csv"
        failed_filename = f"{original_filename}_failed.csv"
        # Create the full paths for the new files
        success_filename = original_dir / success_filename
        failed_filename = original_dir / failed_filename
        # Save the success and failed DataFrames to separate CSV files
        success.to_csv(success_filename, index=False, encoding='utf-8')
        failed.to_csv(failed_filename, index=False, encoding='utf-8')
     
    except Exception as e:
        logger.error(f"Error processing results file: {e}", exc_info=True)
        display(Markdown(f"❌ Error processing results file: {e}."))
        return

interim_cleanup_and_report()
# Out:
# 2025-04-25 19:43:28,152 - INFO - Loaded results from all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_ccot_full_inference.csv (1500 rows).
# ### Results Summary: 1500 Success, 0 Failed.
# 2025-04-25 19:43:28,158 - INFO - Removed duplicates, remaining 1500 unique QIDs.

# %% [markdown]
# # Cleanup and reporting

# %% [markdown]
# ### Report With Summary Model

# %%
SUMMARY_OUTPUT_CSV = RESULTS_FINAL_DIR.replace(".csv", "_cot_summary.csv")


def results_cleanup_and_report():
    """Final cleanup and report of results."""
    if not Path(RESULTS_FINAL_DIR).is_file(): display(Markdown(f"❌ Results file `{RESULTS_FINAL_DIR}` not found.")); return

    try:
        results_df = pd.read_csv(RESULTS_FINAL_DIR, dtype=str)
        logger.info(f"Loaded results from {RESULTS_FINAL_DIR} ({len(results_df)} rows).")
        
        success = results_df[results_df['status'] == 'Success']
        failed = results_df[results_df['status'] != 'Success']
        logger.info(f"Results Summary: {len(success)} Success, {len(failed)} Failed.")
        display(Markdown(f"### Results Summary: {len(success)} Success, {len(failed)} Failed."))

        avg_duration = results_df['duration_sec'].astype(float).mean()
        logger.info(f"Average duration for successful tasks: {avg_duration:.2f} seconds.")
        display(Markdown(f"### Average Duration: {avg_duration:.2f} seconds."))

        # Sort by 'qid'
        results_df.sort_values(by=['qid'], inplace=True)

        # remove duplicates based on 'qid' and keep the first occurrence
        results_df.drop_duplicates(subset=['qid'], keep='first', inplace=True)
        logger.info(f"Removed duplicates, remaining {len(results_df)} unique QIDs.")

        # remove all unnecessary columns
        columns_to_keep = ['qid', 'pred']
        results_df = results_df[columns_to_keep]

        new_name = SUMMARY_OUTPUT_CSV.replace('.csv', "_") +  time.strftime("%Y%m%d_%H%M%S") + ".csv"
        # Save the cleaned DataFrame to a CSV file
        results_df.to_csv(new_name, index=False, encoding='utf-8')
        logger.info(f"Cleaned results saved to {new_name}.")
        display(Markdown(f"✅ Cleaned results saved to `{new_name}`."))
     
    except Exception as e:
        logger.error(f"Error processing results file: {e}", exc_info=True)
        display(Markdown(f"❌ Error processing results file: {e}."))
        return
  
results_cleanup_and_report()
# Out:
# 2025-04-25 19:42:39,389 - INFO - Loaded results from all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_ccot_full_inference.csv (1500 rows).
# 2025-04-25 19:42:39,391 - INFO - Results Summary: 1500 Success, 0 Failed.
# ### Results Summary: 1500 Success, 0 Failed.
# 2025-04-25 19:42:39,394 - INFO - Average duration for successful tasks: 16.02 seconds.
# ### Average Duration: 16.02 seconds.
# 2025-04-25 19:42:39,398 - INFO - Removed duplicates, remaining 1500 unique QIDs.
# 2025-04-25 19:42:39,405 - INFO - Cleaned results saved to all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_ccot_full_inference_cot_summary_20250425_194239.csv.
# ✅ Cleaned results saved to `all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_ccot_full_inference_cot_summary_20250425_194239.csv`.

# %% [markdown]
# ### Getting COT Thinking Process Only

# %%
COT_ONLY_OUTPUT_CSV = RESULTS_FINAL_DIR.replace(".csv", "_cot_only.csv")

def results_cleanup_and_report():
    """Final cleanup and report of results."""
    if not Path(RESULTS_FINAL_DIR).is_file(): display(Markdown(f"❌ Results file `{RESULTS_FINAL_DIR}` not found.")); return

    try:
        results_df = pd.read_csv(RESULTS_FINAL_DIR, dtype=str)
        logger.info(f"Loaded results from {RESULTS_FINAL_DIR} ({len(results_df)} rows).")
        
        success = results_df[results_df['status'] == 'Success']
        failed = results_df[results_df['status'] != 'Success']
        logger.info(f"Results Summary: {len(success)} Success, {len(failed)} Failed.")
        display(Markdown(f"### Results Summary: {len(success)} Success, {len(failed)} Failed."))

        avg_duration = results_df['duration_sec'].astype(float).mean()
        logger.info(f"Average duration for successful tasks: {avg_duration:.2f} seconds.")
        display(Markdown(f"### Average Duration: {avg_duration:.2f} seconds."))

        # Sort by 'qid'
        results_df.sort_values(by=['qid'], inplace=True)

        # remove duplicates based on 'qid' and keep the first occurrence
        results_df.drop_duplicates(subset=['qid'], keep='first', inplace=True)
        logger.info(f"Removed duplicates, remaining {len(results_df)} unique QIDs.")

        # select only the relevant columns
        results_df = results_df[['qid', 'CoT']]

        # Rename column
        results_df.rename(columns={'CoT': 'pred'}, inplace=True)

        new_name = COT_ONLY_OUTPUT_CSV.replace('.csv', "_") +  time.strftime("%Y%m%d_%H%M%S") + ".csv"
    
        # Save the cleaned DataFrame to a CSV file
        results_df.to_csv(new_name, index=False, encoding='utf-8')
        logger.info(f"Cleaned results saved to {new_name}.")
        display(Markdown(f"✅ Cleaned results saved to `{new_name}`."))
     
    except Exception as e:
        logger.error(f"Error processing results file: {e}", exc_info=True)
        display(Markdown(f"❌ Error processing results file: {e}."))
        return
  
results_cleanup_and_report()
# Out:
# 2025-04-25 19:42:42,161 - INFO - Loaded results from all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_ccot_full_inference.csv (1500 rows).
# 2025-04-25 19:42:42,163 - INFO - Results Summary: 1500 Success, 0 Failed.
# ### Results Summary: 1500 Success, 0 Failed.
# 2025-04-25 19:42:42,166 - INFO - Average duration for successful tasks: 16.02 seconds.
# ### Average Duration: 16.02 seconds.
# 2025-04-25 19:42:42,170 - INFO - Removed duplicates, remaining 1500 unique QIDs.
# 2025-04-25 19:42:42,197 - INFO - Cleaned results saved to all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_ccot_full_inference_cot_only_20250425_194242.csv.
# ✅ Cleaned results saved to `all_results/full_inference_CoCoT_heuristics_summary/gemini-2.5-pro-preview-03-25/results_ccot_full_inference_cot_only_20250425_194242.csv`.

# %% [markdown]
# ### Delete original results file if needed

# %%
os.remove(RESULTS_FINAL_DIR) # Remove the original results file
os.remove(RESULTS_FINAL_DIR.replace(".csv", "_failed.csv")) # Remove the failed results file
